# %% [markdown]
# <a href="https://colab.research.google.com/github/bajibaji01/polypeptide_z/blob/main/af/examples/af_cyc_design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #af_cyc_design
#
# **Cyclic peptide structure prediction and design using AlphaFold**
#
# Stephen Rettie, Katelyn Campbell, Asim Bera, Alex Kang, Simon Kozlov, Joshmyn De La Cruz, Victor Adebomi, Guangfeng Zhou, Frank DiMaio, Sergey Ovchinnikov, Gaurav Bhardwaj
#
# doi: https://doi.org/10.1101/2023.02.25.529956

# %%
#@title setup (~2 minutes)
# %%time
import os
if not os.path.isdir("params"):
  # get code
  os.system("pip -q install git+https://github.com/sokrypton/ColabDesign.git@v1.1.1")
  # for debugging
  os.system("ln -s /usr/local/lib/python3.*/dist-packages/colabdesign colabdesign")
  # download params
  os.system("mkdir params")
  os.system("apt-get install aria2 -qq")
  os.system("aria2c -q -x 16 https://storage.googleapis.com/alphafold/alphafold_params_2022-12-06.tar")
  os.system("tar -xf alphafold_params_2022-12-06.tar -C params")

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
from colabdesign import mk_afdesign_model, clear_mem
from IPython.display import HTML
from google.colab import files
import numpy as np

import jax
import jax.numpy as jnp
from colabdesign.af.alphafold.common import residue_constants

def get_pdb(pdb_code=""):
  if pdb_code is None or pdb_code == "":
    upload_dict = files.upload()
    pdb_string = upload_dict[list(upload_dict.keys())[0]]
    with open("tmp.pdb","wb") as out: out.write(pdb_string)
    return "tmp.pdb"
  elif os.path.isfile(pdb_code):
    return pdb_code
  elif len(pdb_code) == 4:
    os.system(f"wget -qnc https://files.rcsb.org/view/{pdb_code}.pdb")
    return f"{pdb_code}.pdb"
  else:
    os.system(f"wget -qnc https://alphafold.ebi.ac.uk/files/AF-{pdb_code}-F1-model_v3.pdb")
    return f"AF-{pdb_code}-F1-model_v3.pdb"

def add_cyclic_offset(self, offset_type=2):
  '''add cyclic offset to connect N and C term'''
  def cyclic_offset(L):
    i = np.arange(L)
    ij = np.stack([i,i+L],-1)
    offset = i[:,None] - i[None,:]
    c_offset = np.abs(ij[:,None,:,None] - ij[None,:,None,:]).min((2,3))
    if offset_type == 1:
      c_offset = c_offset
    elif offset_type >= 2:
      a = c_offset < np.abs(offset)
      c_offset[a] = -c_offset[a]
    if offset_type == 3:
      idx = np.abs(c_offset) > 2
      c_offset[idx] = (32 * c_offset[idx] )/  abs(c_offset[idx])
    return c_offset * np.sign(offset)
  idx = self._inputs["residue_index"]
  offset = np.array(idx[:,None] - idx[None,:])

  if self.protocol == "binder":
    c_offset = cyclic_offset(self._binder_len)
    offset[self._target_len:,self._target_len:] = c_offset

  if self.protocol in ["fixbb","partial","hallucination"]:
    Ln = 0
    for L in self._lengths:
      offset[Ln:Ln+L,Ln:Ln+L] = cyclic_offset(L)
      Ln += L
  self._inputs["offset"] = offset

def add_rg_loss(self, weight=0.1):
  '''add radius of gyration loss'''
  def loss_fn(inputs, outputs):
    xyz = outputs["structure_module"]
    ca = xyz["final_atom_positions"][:,residue_constants.atom_order["CA"]]
    rg = jnp.sqrt(jnp.square(ca - ca.mean(0)).sum(-1).mean() + 1e-8)
    rg_th = 2.38 * ca.shape[0] ** 0.365
    rg = jax.nn.elu(rg - rg_th)
    return {"rg":rg}
  self._callbacks["model"]["loss"].append(loss_fn)
  self.opt["weights"]["rg"] = weight
# Out:
# CPU times: user 1.26 s, sys: 199 ms, total: 1.46 s
# Wall time: 1min 47s

# %% [markdown]
# # fixed backbone design (fixbb) (~2 minutes)
# For a given protein backbone, generate/design a new sequence that AlphaFold thinks folds into that conformation.

# %%
clear_mem()
af_model = mk_afdesign_model(protocol="fixbb")
af_model.prep_inputs(pdb_filename=get_pdb("7m28"), chain="A")
add_cyclic_offset(af_model, offset_type=2)

print("length",  af_model._len)
print("weights", af_model.opt["weights"])
# Out:
# length 7
# weights {'con': 0.0, 'dgram_cce': 1.0, 'exp_res': 0.0, 'fape': 0.0, 'helix': 0.0, 'pae': 0.0, 'plddt': 0.0, 'rmsd': 0.0, 'seq_ent': 0.0}

# %%
import matplotlib.pyplot as plt
plt.imshow(af_model._inputs["offset"],cmap="bwr")

# %%
af_model.restart()
af_model.design_3stage()
# Out:
# Stage 1: running (logits → soft)
# 1 models [4] recycles 0 hard 0 soft 0.00 temp 1 seqid 0 loss 2.49 dgram_cce 2.49 plddt 0.73 ptm 0.06 rmsd 2.29
# 2 models [0] recycles 0 hard 0 soft 0.01 temp 1 seqid 0 loss 2.63 dgram_cce 2.63 plddt 0.77 ptm 0.06 rmsd 1.18
# 3 models [2] recycles 0 hard 0 soft 0.01 temp 1 seqid 0.14 loss 2.63 dgram_cce 2.63 plddt 0.78 ptm 0.06 rmsd 1.39
# 4 models [4] recycles 0 hard 0 soft 0.01 temp 1 seqid 0.29 loss 2.43 dgram_cce 2.43 plddt 0.76 ptm 0.06 rmsd 1.11
# 5 models [3] recycles 0 hard 0 soft 0.02 temp 1 seqid 0.14 loss 2.33 dgram_cce 2.33 plddt 0.78 ptm 0.05 rmsd 0.95
# 6 models [0] recycles 0 hard 0 soft 0.02 temp 1 seqid 0.14 loss 2.40 dgram_cce 2.40 plddt 0.85 ptm 0.06 rmsd 1.39
# 7 models [2] recycles 0 hard 0 soft 0.02 temp 1 seqid 0 loss 2.23 dgram_cce 2.23 plddt 0.72 ptm 0.06 rmsd 1.38
# 8 models [4] recycles 0 hard 0 soft 0.03 temp 1 seqid 0 loss 2.28 dgram_cce 2.28 plddt 0.79 ptm 0.06 rmsd 1.09
# 9 models [0] recycles 0 hard 0 soft 0.03 temp 1 seqid 0 loss 2.27 dgram_cce 2.27 plddt 0.80 ptm 0.06 rmsd 1.09
# 10 models [1] recycles 0 hard 0 soft 0.03 temp 1 seqid 0 loss 2.22 dgram_cce 2.22 plddt 0.76 ptm 0.06 rmsd 1.22
# 11 models [1] recycles 0 hard 0 soft 0.04 temp 1 seqid 0 loss 2.13 dgram_cce 2.13 plddt 0.72 ptm 0.06 rmsd 0.87
# 12 models [2] recycles 0 hard 0 soft 0.04 temp 1 seqid 0 loss 2.12 dgram_cce 2.12 plddt 0.80 ptm 0.06 rmsd 1.12
# 13 models [2] recycles 0 hard 0 soft 0.04 temp 1 seqid 0 loss 2.14 dgram_cce 2.14 plddt 0.84 ptm 0.06 rmsd 0.98
# 14 models [1] recycles 0 hard 0 soft 0.05 temp 1 seqid 0 loss 2.09 dgram_cce 2.09 plddt 0.81 ptm 0.06 rmsd 0.59
# 15 models [1] recycles 0 hard 0 soft 0.05 temp 1 seqid 0 loss 2.13 dgram_cce 2.13 plddt 0.80 ptm 0.06 rmsd 0.56
# 16 models [4] recycles 0 hard 0 soft 0.05 temp 1 seqid 0 loss 2.11 dgram_cce 2.11 plddt 0.88 ptm 0.06 rmsd 1.06
# 17 models [0] recycles 0 hard 0 soft 0.06 temp 1 seqid 0 loss 2.05 dgram_cce 2.05 plddt 0.86 ptm 0.06 rmsd 0.76
# 18 models [2] recycles 0 hard 0 soft 0.06 temp 1 seqid 0 loss 2.09 dgram_cce 2.09 plddt 0.82 ptm 0.06 rmsd 0.81
# 19 models [2] recycles 0 hard 0 soft 0.06 temp 1 seqid 0 loss 1.99 dgram_cce 1.99 plddt 0.79 ptm 0.06 rmsd 0.84
# 20 models [3] recycles 0 hard 0 soft 0.07 temp 1 seqid 0.14 loss 1.95 dgram_cce 1.95 plddt 0.84 ptm 0.06 rmsd 0.83
# 21 models [4] recycles 0 hard 0 soft 0.07 temp 1 seqid 0 loss 1.99 dgram_cce 1.99 plddt 0.86 ptm 0.06 rmsd 0.78
# 22 models [0] recycles 0 hard 0 soft 0.07 temp 1 seqid 0 loss 1.99 dgram_cce 1.99 plddt 0.86 ptm 0.06 rmsd 0.55
# 23 models [4] recycles 0 hard 0 soft 0.08 temp 1 seqid 0 loss 1.91 dgram_cce 1.91 plddt 0.83 ptm 0.06 rmsd 0.94
# 24 models [4] recycles 0 hard 0 soft 0.08 temp 1 seqid 0 loss 1.93 dgram_cce 1.93 plddt 0.86 ptm 0.06 rmsd 0.66
# 25 models [3] recycles 0 hard 0 soft 0.08 temp 1 seqid 0 loss 1.93 dgram_cce 1.93 plddt 0.82 ptm 0.06 rmsd 0.85
# 26 models [3] recycles 0 hard 0 soft 0.09 temp 1 seqid 0 loss 1.97 dgram_cce 1.97 plddt 0.87 ptm 0.06 rmsd 0.88
# 27 models [1] recycles 0 hard 0 soft 0.09 temp 1 seqid 0 loss 2.07 dgram_cce 2.07 plddt 0.83 ptm 0.06 rmsd 0.96
# 28 models [1] recycles 0 hard 0 soft 0.09 temp 1 seqid 0 loss 2.03 dgram_cce 2.03 plddt 0.84 ptm 0.06 rmsd 0.79
# 29 models [0] recycles 0 hard 0 soft 0.10 temp 1 seqid 0 loss 1.99 dgram_cce 1.99 plddt 0.87 ptm 0.06 rmsd 0.58
# 30 models [4] recycles 0 hard 0 soft 0.10 temp 1 seqid 0 loss 2.05 dgram_cce 2.05 plddt 0.79 ptm 0.06 rmsd 1.06
# 31 models [1] recycles 0 hard 0 soft 0.10 temp 1 seqid 0 loss 2.15 dgram_cce 2.15 plddt 0.77 ptm 0.06 rmsd 0.79
# 32 models [2] recycles 0 hard 0 soft 0.11 temp 1 seqid 0.14 loss 2.57 dgram_cce 2.57 plddt 0.72 ptm 0.06 rmsd 1.78
# 33 models [4] recycles 0 hard 0 soft 0.11 temp 1 seqid 0.14 loss 2.37 dgram_cce 2.37 plddt 0.60 ptm 0.06 rmsd 1.81
# 34 models [3] recycles 0 hard 0 soft 0.11 temp 1 seqid 0 loss 2.50 dgram_cce 2.50 plddt 0.62 ptm 0.06 rmsd 1.72
# 35 models [1] recycles 0 hard 0 soft 0.12 temp 1 seqid 0 loss 2.40 dgram_cce 2.40 plddt 0.67 ptm 0.06 rmsd 2.89
# 36 models [2] recycles 0 hard 0 soft 0.12 temp 1 seqid 0 loss 2.43 dgram_cce 2.43 plddt 0.74 ptm 0.06 rmsd 1.46
# 37 models [4] recycles 0 hard 0 soft 0.12 temp 1 seqid 0 loss 2.91 dgram_cce 2.91 plddt 0.61 ptm 0.05 rmsd 3.01
# 38 models [3] recycles 0 hard 0 soft 0.13 temp 1 seqid 0 loss 2.46 dgram_cce 2.46 plddt 0.69 ptm 0.06 rmsd 3.18
# 39 models [3] recycles 0 hard 0 soft 0.13 temp 1 seqid 0 loss 2.22 dgram_cce 2.22 plddt 0.74 ptm 0.06 rmsd 1.59
# 40 models [1] recycles 0 hard 0 soft 0.13 temp 1 seqid 0 loss 1.96 dgram_cce 1.96 plddt 0.82 ptm 0.06 rmsd 0.68
# 41 models [1] recycles 0 hard 0 soft 0.14 temp 1 seqid 0 loss 2.10 dgram_cce 2.10 plddt 0.78 ptm 0.06 rmsd 1.16
# 42 models [3] recycles 0 hard 0 soft 0.14 temp 1 seqid 0 loss 2.01 dgram_cce 2.01 plddt 0.89 ptm 0.06 rmsd 0.93
# 43 models [3] recycles 0 hard 0 soft 0.14 temp 1 seqid 0 loss 1.97 dgram_cce 1.97 plddt 0.87 ptm 0.06 rmsd 0.76
# 44 models [1] recycles 0 hard 0 soft 0.15 temp 1 seqid 0 loss 1.96 dgram_cce 1.96 plddt 0.80 ptm 0.06 rmsd 0.83
# 45 models [0] recycles 0 hard 0 soft 0.15 temp 1 seqid 0 loss 2.16 dgram_cce 2.16 plddt 0.81 ptm 0.06 rmsd 0.62
# 46 models [2] recycles 0 hard 0 soft 0.15 temp 1 seqid 0 loss 1.98 dgram_cce 1.98 plddt 0.88 ptm 0.06 rmsd 1.02
# 47 models [2] recycles 0 hard 0 soft 0.16 temp 1 seqid 0 loss 2.17 dgram_cce 2.17 plddt 0.81 ptm 0.06 rmsd 1.50
# 48 models [4] recycles 0 hard 0 soft 0.16 temp 1 seqid 0 loss 2.04 dgram_cce 2.04 plddt 0.86 ptm 0.06 rmsd 0.86
# 49 models [1] recycles 0 hard 0 soft 0.16 temp 1 seqid 0 loss 2.07 dgram_cce 2.07 plddt 0.83 ptm 0.06 rmsd 1.14
# 50 models [3] recycles 0 hard 0 soft 0.17 temp 1 seqid 0 loss 2.13 dgram_cce 2.13 plddt 0.77 ptm 0.06 rmsd 0.98
# 51 models [2] recycles 0 hard 0 soft 0.17 temp 1 seqid 0 loss 2.02 dgram_cce 2.02 plddt 0.89 ptm 0.06 rmsd 0.78
# 52 models [3] recycles 0 hard 0 soft 0.17 temp 1 seqid 0 loss 1.90 dgram_cce 1.90 plddt 0.88 ptm 0.06 rmsd 0.78
# 53 models [1] recycles 0 hard 0 soft 0.18 temp 1 seqid 0 loss 1.98 dgram_cce 1.98 plddt 0.82 ptm 0.06 rmsd 0.69
# 54 models [0] recycles 0 hard 0 soft 0.18 temp 1 seqid 0 loss 2.04 dgram_cce 2.04 plddt 0.82 ptm 0.06 rmsd 0.87
# 55 models [0] recycles 0 hard 0 soft 0.18 temp 1 seqid 0 loss 1.92 dgram_cce 1.92 plddt 0.88 ptm 0.06 rmsd 0.73
# 56 models [3] recycles 0 hard 0 soft 0.19 temp 1 seqid 0 loss 2.04 dgram_cce 2.04 plddt 0.88 ptm 0.06 rmsd 1.06
# 57 models [2] recycles 0 hard 0 soft 0.19 temp 1 seqid 0 loss 1.91 dgram_cce 1.91 plddt 0.86 ptm 0.06 rmsd 0.80
# 58 models [4] recycles 0 hard 0 soft 0.19 temp 1 seqid 0 loss 2.10 dgram_cce 2.10 plddt 0.89 ptm 0.06 rmsd 1.18
# 59 models [3] recycles 0 hard 0 soft 0.20 temp 1 seqid 0 loss 1.96 dgram_cce 1.96 plddt 0.87 ptm 0.06 rmsd 0.65
# 60 models [4] recycles 0 hard 0 soft 0.20 temp 1 seqid 0 loss 1.95 dgram_cce 1.95 plddt 0.85 ptm 0.06 rmsd 0.96
# 61 models [2] recycles 0 hard 0 soft 0.20 temp 1 seqid 0.14 loss 1.93 dgram_cce 1.93 plddt 0.87 ptm 0.06 rmsd 0.66
# 62 models [4] recycles 0 hard 0 soft 0.21 temp 1 seqid 0.14 loss 1.98 dgram_cce 1.98 plddt 0.85 ptm 0.06 rmsd 0.94
# 63 models [4] recycles 0 hard 0 soft 0.21 temp 1 seqid 0.14 loss 1.88 dgram_cce 1.88 plddt 0.88 ptm 0.06 rmsd 0.79
# 64 models [1] recycles 0 hard 0 soft 0.21 temp 1 seqid 0.14 loss 2.01 dgram_cce 2.01 plddt 0.79 ptm 0.06 rmsd 0.92
# 65 models [4] recycles 0 hard 0 soft 0.22 temp 1 seqid 0.14 loss 1.99 dgram_cce 1.99 plddt 0.86 ptm 0.06 rmsd 1.01
# 66 models [2] recycles 0 hard 0 soft 0.22 temp 1 seqid 0.14 loss 1.94 dgram_cce 1.94 plddt 0.83 ptm 0.06 rmsd 0.84
# 67 models [1] recycles 0 hard 0 soft 0.22 temp 1 seqid 0.14 loss 2.19 dgram_cce 2.19 plddt 0.78 ptm 0.06 rmsd 1.15
# 68 models [3] recycles 0 hard 0 soft 0.23 temp 1 seqid 0.14 loss 1.92 dgram_cce 1.92 plddt 0.87 ptm 0.06 rmsd 0.75
# 69 models [3] recycles 0 hard 0 soft 0.23 temp 1 seqid 0.14 loss 1.92 dgram_cce 1.92 plddt 0.88 ptm 0.06 rmsd 0.70
# 70 models [0] recycles 0 hard 0 soft 0.23 temp 1 seqid 0.14 loss 1.96 dgram_cce 1.96 plddt 0.84 ptm 0.06 rmsd 0.65
# 71 models [0] recycles 0 hard 0 soft 0.24 temp 1 seqid 0.14 loss 1.86 dgram_cce 1.86 plddt 0.87 ptm 0.06 rmsd 0.72
# 72 models [1] recycles 0 hard 0 soft 0.24 temp 1 seqid 0.14 loss 2.26 dgram_cce 2.26 plddt 0.64 ptm 0.06 rmsd 3.21
# 73 models [2] recycles 0 hard 0 soft 0.24 temp 1 seqid 0.14 loss 2.08 dgram_cce 2.08 plddt 0.78 ptm 0.06 rmsd 1.37
# 74 models [4] recycles 0 hard 0 soft 0.25 temp 1 seqid 0.14 loss 2.27 dgram_cce 2.27 plddt 0.63 ptm 0.06 rmsd 2.01
# 75 models [4] recycles 0 hard 0 soft 0.25 temp 1 seqid 0.14 loss 2.25 dgram_cce 2.25 plddt 0.66 ptm 0.06 rmsd 2.01
# 76 models [4] recycles 0 hard 0 soft 0.25 temp 1 seqid 0.14 loss 2.33 dgram_cce 2.33 plddt 0.66 ptm 0.06 rmsd 1.44
# 77 models [1] recycles 0 hard 0 soft 0.26 temp 1 seqid 0.14 loss 2.25 dgram_cce 2.25 plddt 0.75 ptm 0.06 rmsd 1.73
# 78 models [4] recycles 0 hard 0 soft 0.26 temp 1 seqid 0.14 loss 2.46 dgram_cce 2.46 plddt 0.63 ptm 0.06 rmsd 3.47
# 79 models [4] recycles 0 hard 0 soft 0.26 temp 1 seqid 0.14 loss 1.91 dgram_cce 1.91 plddt 0.87 ptm 0.06 rmsd 0.79
# 80 models [4] recycles 0 hard 0 soft 0.27 temp 1 seqid 0.14 loss 1.84 dgram_cce 1.84 plddt 0.87 ptm 0.06 rmsd 0.87
# 81 models [4] recycles 0 hard 0 soft 0.27 temp 1 seqid 0.14 loss 1.96 dgram_cce 1.96 plddt 0.82 ptm 0.06 rmsd 0.94
# 82 models [1] recycles 0 hard 0 soft 0.27 temp 1 seqid 0.14 loss 1.93 dgram_cce 1.93 plddt 0.73 ptm 0.06 rmsd 0.80
# 83 models [3] recycles 0 hard 0 soft 0.28 temp 1 seqid 0.14 loss 2.18 dgram_cce 2.18 plddt 0.75 ptm 0.06 rmsd 1.18
# 84 models [4] recycles 0 hard 0 soft 0.28 temp 1 seqid 0.14 loss 1.95 dgram_cce 1.95 plddt 0.79 ptm 0.06 rmsd 0.69
# 85 models [1] recycles 0 hard 0 soft 0.28 temp 1 seqid 0.14 loss 1.71 dgram_cce 1.71 plddt 0.84 ptm 0.06 rmsd 0.65
# 86 models [2] recycles 0 hard 0 soft 0.29 temp 1 seqid 0 loss 1.89 dgram_cce 1.89 plddt 0.84 ptm 0.06 rmsd 0.69
# 87 models [1] recycles 0 hard 0 soft 0.29 temp 1 seqid 0.14 loss 2.09 dgram_cce 2.09 plddt 0.74 ptm 0.06 rmsd 1.20
# 88 models [3] recycles 0 hard 0 soft 0.29 temp 1 seqid 0.14 loss 1.83 dgram_cce 1.83 plddt 0.84 ptm 0.06 rmsd 0.65
# 89 models [2] recycles 0 hard 0 soft 0.30 temp 1 seqid 0.14 loss 1.85 dgram_cce 1.85 plddt 0.83 ptm 0.06 rmsd 0.62
# 90 models [3] recycles 0 hard 0 soft 0.30 temp 1 seqid 0.14 loss 1.86 dgram_cce 1.86 plddt 0.87 ptm 0.06 rmsd 0.77
# 91 models [0] recycles 0 hard 0 soft 0.30 temp 1 seqid 0.14 loss 1.91 dgram_cce 1.91 plddt 0.88 ptm 0.06 rmsd 0.91
# 92 models [0] recycles 0 hard 0 soft 0.31 temp 1 seqid 0.14 loss 2.18 dgram_cce 2.18 plddt 0.78 ptm 0.06 rmsd 0.92
# 93 models [1] recycles 0 hard 0 soft 0.31 temp 1 seqid 0.14 loss 1.89 dgram_cce 1.89 plddt 0.83 ptm 0.06 rmsd 0.54
# 94 models [0] recycles 0 hard 0 soft 0.31 temp 1 seqid 0.14 loss 1.77 dgram_cce 1.77 plddt 0.86 ptm 0.06 rmsd 0.57
# 95 models [3] recycles 0 hard 0 soft 0.32 temp 1 seqid 0.14 loss 2.02 dgram_cce 2.02 plddt 0.81 ptm 0.06 rmsd 1.02
# 96 models [1] recycles 0 hard 0 soft 0.32 temp 1 seqid 0.14 loss 1.81 dgram_cce 1.81 plddt 0.85 ptm 0.06 rmsd 0.62
# 97 models [2] recycles 0 hard 0 soft 0.32 temp 1 seqid 0 loss 1.80 dgram_cce 1.80 plddt 0.81 ptm 0.06 rmsd 0.74
# 98 models [4] recycles 0 hard 0 soft 0.33 temp 1 seqid 0 loss 1.89 dgram_cce 1.89 plddt 0.77 ptm 0.06 rmsd 1.25
# 99 models [3] recycles 0 hard 0 soft 0.33 temp 1 seqid 0.14 loss 1.92 dgram_cce 1.92 plddt 0.82 ptm 0.06 rmsd 1.13
# 100 models [2] recycles 0 hard 0 soft 0.33 temp 1 seqid 0.14 loss 1.83 dgram_cce 1.83 plddt 0.86 ptm 0.06 rmsd 0.88
# 101 models [2] recycles 0 hard 0 soft 0.34 temp 1 seqid 0.14 loss 1.82 dgram_cce 1.82 plddt 0.78 ptm 0.06 rmsd 0.67
# 102 models [0] recycles 0 hard 0 soft 0.34 temp 1 seqid 0.14 loss 2.38 dgram_cce 2.38 plddt 0.66 ptm 0.06 rmsd 1.88
# 103 models [3] recycles 0 hard 0 soft 0.34 temp 1 seqid 0.14 loss 1.96 dgram_cce 1.96 plddt 0.82 ptm 0.06 rmsd 1.15
# 104 models [0] recycles 0 hard 0 soft 0.35 temp 1 seqid 0.14 loss 1.71 dgram_cce 1.71 plddt 0.87 ptm 0.06 rmsd 0.63
# 105 models [2] recycles 0 hard 0 soft 0.35 temp 1 seqid 0.14 loss 1.89 dgram_cce 1.89 plddt 0.82 ptm 0.06 rmsd 0.74
# 106 models [0] recycles 0 hard 0 soft 0.35 temp 1 seqid 0.14 loss 1.94 dgram_cce 1.94 plddt 0.84 ptm 0.06 rmsd 0.76
# 107 models [2] recycles 0 hard 0 soft 0.36 temp 1 seqid 0.14 loss 1.73 dgram_cce 1.73 plddt 0.81 ptm 0.06 rmsd 0.49
# 108 models [2] recycles 0 hard 0 soft 0.36 temp 1 seqid 0.14 loss 1.67 dgram_cce 1.67 plddt 0.84 ptm 0.06 rmsd 0.64
# 109 models [2] recycles 0 hard 0 soft 0.36 temp 1 seqid 0.14 loss 1.75 dgram_cce 1.75 plddt 0.80 ptm 0.06 rmsd 0.63
# 110 models [1] recycles 0 hard 0 soft 0.37 temp 1 seqid 0.14 loss 2.20 dgram_cce 2.20 plddt 0.75 ptm 0.06 rmsd 1.76
# 111 models [3] recycles 0 hard 0 soft 0.37 temp 1 seqid 0.14 loss 2.24 dgram_cce 2.24 plddt 0.70 ptm 0.06 rmsd 2.53
# 112 models [0] recycles 0 hard 0 soft 0.37 temp 1 seqid 0.14 loss 1.89 dgram_cce 1.89 plddt 0.87 ptm 0.06 rmsd 0.67
# 113 models [1] recycles 0 hard 0 soft 0.38 temp 1 seqid 0.14 loss 1.69 dgram_cce 1.69 plddt 0.83 ptm 0.06 rmsd 0.59
# 114 models [0] recycles 0 hard 0 soft 0.38 temp 1 seqid 0.14 loss 2.03 dgram_cce 2.03 plddt 0.80 ptm 0.06 rmsd 0.86
# 115 models [3] recycles 0 hard 0 soft 0.38 temp 1 seqid 0.14 loss 1.84 dgram_cce 1.84 plddt 0.88 ptm 0.06 rmsd 0.76
# 116 models [2] recycles 0 hard 0 soft 0.39 temp 1 seqid 0.14 loss 1.86 dgram_cce 1.86 plddt 0.86 ptm 0.06 rmsd 1.00
# 117 models [2] recycles 0 hard 0 soft 0.39 temp 1 seqid 0.14 loss 1.79 dgram_cce 1.79 plddt 0.82 ptm 0.06 rmsd 0.63
# 118 models [4] recycles 0 hard 0 soft 0.39 temp 1 seqid 0.14 loss 1.73 dgram_cce 1.73 plddt 0.83 ptm 0.06 rmsd 0.75
# 119 models [1] recycles 0 hard 0 soft 0.40 temp 1 seqid 0.14 loss 1.91 dgram_cce 1.91 plddt 0.82 ptm 0.06 rmsd 0.72
# 120 models [1] recycles 0 hard 0 soft 0.40 temp 1 seqid 0.14 loss 1.76 dgram_cce 1.76 plddt 0.88 ptm 0.06 rmsd 0.65
# 121 models [1] recycles 0 hard 0 soft 0.40 temp 1 seqid 0.14 loss 1.80 dgram_cce 1.80 plddt 0.88 ptm 0.06 rmsd 0.85
# 122 models [1] recycles 0 hard 0 soft 0.41 temp 1 seqid 0.14 loss 1.77 dgram_cce 1.77 plddt 0.82 ptm 0.06 rmsd 0.67
# 123 models [1] recycles 0 hard 0 soft 0.41 temp 1 seqid 0.14 loss 1.78 dgram_cce 1.78 plddt 0.88 ptm 0.06 rmsd 0.79
# 124 models [0] recycles 0 hard 0 soft 0.41 temp 1 seqid 0.14 loss 1.74 dgram_cce 1.74 plddt 0.81 ptm 0.06 rmsd 0.70
# 125 models [0] recycles 0 hard 0 soft 0.42 temp 1 seqid 0.14 loss 1.81 dgram_cce 1.81 plddt 0.86 ptm 0.06 rmsd 0.71
# 126 models [4] recycles 0 hard 0 soft 0.42 temp 1 seqid 0.14 loss 1.83 dgram_cce 1.83 plddt 0.87 ptm 0.06 rmsd 0.70
# 127 models [0] recycles 0 hard 0 soft 0.42 temp 1 seqid 0.14 loss 1.75 dgram_cce 1.75 plddt 0.89 ptm 0.06 rmsd 0.69
# 128 models [4] recycles 0 hard 0 soft 0.43 temp 1 seqid 0.14 loss 1.81 dgram_cce 1.81 plddt 0.82 ptm 0.06 rmsd 0.80
# 129 models [4] recycles 0 hard 0 soft 0.43 temp 1 seqid 0.14 loss 2.47 dgram_cce 2.47 plddt 0.79 ptm 0.06 rmsd 0.98
# 130 models [2] recycles 0 hard 0 soft 0.43 temp 1 seqid 0.14 loss 1.97 dgram_cce 1.97 plddt 0.87 ptm 0.06 rmsd 0.79
# 131 models [2] recycles 0 hard 0 soft 0.44 temp 1 seqid 0.14 loss 1.86 dgram_cce 1.86 plddt 0.85 ptm 0.06 rmsd 0.48
# 132 models [2] recycles 0 hard 0 soft 0.44 temp 1 seqid 0.14 loss 1.85 dgram_cce 1.85 plddt 0.90 ptm 0.06 rmsd 0.76
# 133 models [4] recycles 0 hard 0 soft 0.44 temp 1 seqid 0.14 loss 1.88 dgram_cce 1.88 plddt 0.84 ptm 0.06 rmsd 0.79
# 134 models [0] recycles 0 hard 0 soft 0.45 temp 1 seqid 0.14 loss 1.88 dgram_cce 1.88 plddt 0.91 ptm 0.06 rmsd 0.77
# 135 models [2] recycles 0 hard 0 soft 0.45 temp 1 seqid 0.14 loss 1.78 dgram_cce 1.78 plddt 0.86 ptm 0.06 rmsd 0.78
# 136 models [2] recycles 0 hard 0 soft 0.45 temp 1 seqid 0.14 loss 1.76 dgram_cce 1.76 plddt 0.86 ptm 0.06 rmsd 0.60
# 137 models [2] recycles 0 hard 0 soft 0.46 temp 1 seqid 0.14 loss 1.89 dgram_cce 1.89 plddt 0.84 ptm 0.06 rmsd 0.63
# 138 models [4] recycles 0 hard 0 soft 0.46 temp 1 seqid 0.14 loss 2.16 dgram_cce 2.16 plddt 0.78 ptm 0.06 rmsd 1.49
# 139 models [1] recycles 0 hard 0 soft 0.46 temp 1 seqid 0.14 loss 1.79 dgram_cce 1.79 plddt 0.84 ptm 0.06 rmsd 0.74
# 140 models [3] recycles 0 hard 0 soft 0.47 temp 1 seqid 0.14 loss 1.83 dgram_cce 1.83 plddt 0.82 ptm 0.06 rmsd 0.81
# 141 models [1] recycles 0 hard 0 soft 0.47 temp 1 seqid 0.14 loss 2.00 dgram_cce 2.00 plddt 0.82 ptm 0.06 rmsd 1.17
# 142 models [4] recycles 0 hard 0 soft 0.47 temp 1 seqid 0.14 loss 1.81 dgram_cce 1.81 plddt 0.82 ptm 0.06 rmsd 0.72
# 143 models [0] recycles 0 hard 0 soft 0.48 temp 1 seqid 0.14 loss 2.02 dgram_cce 2.02 plddt 0.85 ptm 0.06 rmsd 0.61
# 144 models [0] recycles 0 hard 0 soft 0.48 temp 1 seqid 0.14 loss 1.96 dgram_cce 1.96 plddt 0.83 ptm 0.06 rmsd 0.83
# 145 models [3] recycles 0 hard 0 soft 0.48 temp 1 seqid 0.14 loss 1.88 dgram_cce 1.88 plddt 0.84 ptm 0.06 rmsd 0.74
# 146 models [1] recycles 0 hard 0 soft 0.49 temp 1 seqid 0.14 loss 1.81 dgram_cce 1.81 plddt 0.85 ptm 0.06 rmsd 0.49
# 147 models [3] recycles 0 hard 0 soft 0.49 temp 1 seqid 0.14 loss 1.88 dgram_cce 1.88 plddt 0.89 ptm 0.06 rmsd 0.66
# 148 models [3] recycles 0 hard 0 soft 0.49 temp 1 seqid 0.14 loss 1.78 dgram_cce 1.78 plddt 0.79 ptm 0.06 rmsd 0.86
# 149 models [4] recycles 0 hard 0 soft 0.50 temp 1 seqid 0.14 loss 1.84 dgram_cce 1.84 plddt 0.84 ptm 0.06 rmsd 0.82
# 150 models [2] recycles 0 hard 0 soft 0.50 temp 1 seqid 0.14 loss 1.92 dgram_cce 1.92 plddt 0.87 ptm 0.06 rmsd 0.87
# 151 models [2] recycles 0 hard 0 soft 0.50 temp 1 seqid 0.14 loss 1.76 dgram_cce 1.76 plddt 0.89 ptm 0.06 rmsd 0.74
# 152 models [1] recycles 0 hard 0 soft 0.51 temp 1 seqid 0.14 loss 1.74 dgram_cce 1.74 plddt 0.86 ptm 0.06 rmsd 0.44
# 153 models [0] recycles 0 hard 0 soft 0.51 temp 1 seqid 0.14 loss 1.76 dgram_cce 1.76 plddt 0.88 ptm 0.06 rmsd 0.71
# 154 models [2] recycles 0 hard 0 soft 0.51 temp 1 seqid 0.14 loss 1.82 dgram_cce 1.82 plddt 0.88 ptm 0.06 rmsd 0.69
# 155 models [4] recycles 0 hard 0 soft 0.52 temp 1 seqid 0.14 loss 1.86 dgram_cce 1.86 plddt 0.86 ptm 0.06 rmsd 0.72
# 156 models [4] recycles 0 hard 0 soft 0.52 temp 1 seqid 0.14 loss 1.94 dgram_cce 1.94 plddt 0.88 ptm 0.06 rmsd 0.56
# 157 models [1] recycles 0 hard 0 soft 0.52 temp 1 seqid 0.14 loss 1.51 dgram_cce 1.51 plddt 0.84 ptm 0.06 rmsd 0.58
# 158 models [2] recycles 0 hard 0 soft 0.53 temp 1 seqid 0.14 loss 1.71 dgram_cce 1.71 plddt 0.87 ptm 0.06 rmsd 0.58
# 159 models [3] recycles 0 hard 0 soft 0.53 temp 1 seqid 0.14 loss 1.66 dgram_cce 1.66 plddt 0.90 ptm 0.06 rmsd 0.59
# 160 models [0] recycles 0 hard 0 soft 0.53 temp 1 seqid 0.14 loss 1.99 dgram_cce 1.99 plddt 0.79 ptm 0.06 rmsd 0.65
# 161 models [1] recycles 0 hard 0 soft 0.54 temp 1 seqid 0.14 loss 1.50 dgram_cce 1.50 plddt 0.92 ptm 0.07 rmsd 0.76
# 162 models [4] recycles 0 hard 0 soft 0.54 temp 1 seqid 0.14 loss 1.86 dgram_cce 1.86 plddt 0.89 ptm 0.06 rmsd 0.75
# 163 models [2] recycles 0 hard 0 soft 0.54 temp 1 seqid 0.14 loss 1.62 dgram_cce 1.62 plddt 0.88 ptm 0.06 rmsd 0.78
# 164 models [1] recycles 0 hard 0 soft 0.55 temp 1 seqid 0.14 loss 1.58 dgram_cce 1.58 plddt 0.88 ptm 0.07 rmsd 0.42
# 165 models [0] recycles 0 hard 0 soft 0.55 temp 1 seqid 0.29 loss 1.95 dgram_cce 1.95 plddt 0.88 ptm 0.06 rmsd 0.49
# 166 models [1] recycles 0 hard 0 soft 0.55 temp 1 seqid 0.14 loss 1.39 dgram_cce 1.39 plddt 0.89 ptm 0.07 rmsd 0.35
# 167 models [2] recycles 0 hard 0 soft 0.56 temp 1 seqid 0.29 loss 2.00 dgram_cce 2.00 plddt 0.85 ptm 0.06 rmsd 0.40
# 168 models [4] recycles 0 hard 0 soft 0.56 temp 1 seqid 0.29 loss 1.69 dgram_cce 1.69 plddt 0.88 ptm 0.06 rmsd 0.28
# 169 models [3] recycles 0 hard 0 soft 0.56 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.86 ptm 0.06 rmsd 0.37
# 170 models [4] recycles 0 hard 0 soft 0.57 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.92 ptm 0.06 rmsd 0.37
# 171 models [3] recycles 0 hard 0 soft 0.57 temp 1 seqid 0.29 loss 1.56 dgram_cce 1.56 plddt 0.92 ptm 0.06 rmsd 0.47
# 172 models [3] recycles 0 hard 0 soft 0.57 temp 1 seqid 0.29 loss 1.62 dgram_cce 1.62 plddt 0.84 ptm 0.06 rmsd 0.70
# 173 models [4] recycles 0 hard 0 soft 0.58 temp 1 seqid 0.29 loss 1.76 dgram_cce 1.76 plddt 0.79 ptm 0.06 rmsd 1.18
# 174 models [2] recycles 0 hard 0 soft 0.58 temp 1 seqid 0.29 loss 1.65 dgram_cce 1.65 plddt 0.89 ptm 0.07 rmsd 0.58
# 175 models [4] recycles 0 hard 0 soft 0.58 temp 1 seqid 0.29 loss 1.56 dgram_cce 1.56 plddt 0.87 ptm 0.06 rmsd 0.36
# 176 models [3] recycles 0 hard 0 soft 0.59 temp 1 seqid 0.29 loss 1.66 dgram_cce 1.66 plddt 0.91 ptm 0.06 rmsd 0.56
# 177 models [1] recycles 0 hard 0 soft 0.59 temp 1 seqid 0.29 loss 1.57 dgram_cce 1.57 plddt 0.85 ptm 0.06 rmsd 0.49
# 178 models [3] recycles 0 hard 0 soft 0.59 temp 1 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.88 ptm 0.06 rmsd 0.59
# 179 models [3] recycles 0 hard 0 soft 0.60 temp 1 seqid 0.29 loss 1.52 dgram_cce 1.52 plddt 0.84 ptm 0.06 rmsd 0.52
# 180 models [3] recycles 0 hard 0 soft 0.60 temp 1 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.93 ptm 0.07 rmsd 0.37
# 181 models [3] recycles 0 hard 0 soft 0.60 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.91 ptm 0.06 rmsd 0.39
# 182 models [3] recycles 0 hard 0 soft 0.61 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.92 ptm 0.06 rmsd 0.42
# 183 models [3] recycles 0 hard 0 soft 0.61 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.91 ptm 0.07 rmsd 0.41
# 184 models [2] recycles 0 hard 0 soft 0.61 temp 1 seqid 0.29 loss 1.62 dgram_cce 1.62 plddt 0.93 ptm 0.07 rmsd 0.45
# 185 models [2] recycles 0 hard 0 soft 0.62 temp 1 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.91 ptm 0.07 rmsd 0.32
# 186 models [1] recycles 0 hard 0 soft 0.62 temp 1 seqid 0.29 loss 1.90 dgram_cce 1.90 plddt 0.83 ptm 0.07 rmsd 1.00
# 187 models [3] recycles 0 hard 0 soft 0.62 temp 1 seqid 0.29 loss 1.64 dgram_cce 1.64 plddt 0.92 ptm 0.06 rmsd 0.33
# 188 models [3] recycles 0 hard 0 soft 0.63 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.87 ptm 0.06 rmsd 0.47
# 189 models [1] recycles 0 hard 0 soft 0.63 temp 1 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.82 ptm 0.07 rmsd 0.45
# 190 models [2] recycles 0 hard 0 soft 0.63 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.90 ptm 0.06 rmsd 0.45
# 191 models [3] recycles 0 hard 0 soft 0.64 temp 1 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.91 ptm 0.06 rmsd 0.33
# 192 models [0] recycles 0 hard 0 soft 0.64 temp 1 seqid 0.29 loss 1.34 dgram_cce 1.34 plddt 0.90 ptm 0.07 rmsd 0.28
# 193 models [4] recycles 0 hard 0 soft 0.64 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.87 ptm 0.07 rmsd 0.40
# 194 models [1] recycles 0 hard 0 soft 0.65 temp 1 seqid 0.29 loss 1.29 dgram_cce 1.29 plddt 0.90 ptm 0.07 rmsd 0.39
# 195 models [2] recycles 0 hard 0 soft 0.65 temp 1 seqid 0.29 loss 1.56 dgram_cce 1.56 plddt 0.92 ptm 0.06 rmsd 0.38
# 196 models [2] recycles 0 hard 0 soft 0.65 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.87 ptm 0.06 rmsd 0.45
# 197 models [1] recycles 0 hard 0 soft 0.66 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.91 ptm 0.06 rmsd 0.41
# 198 models [0] recycles 0 hard 0 soft 0.66 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.90 ptm 0.06 rmsd 0.44
# 199 models [3] recycles 0 hard 0 soft 0.66 temp 1 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.91 ptm 0.06 rmsd 0.41
# 200 models [1] recycles 0 hard 0 soft 0.67 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.91 ptm 0.07 rmsd 0.39
# 201 models [2] recycles 0 hard 0 soft 0.67 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.88 ptm 0.07 rmsd 0.34
# 202 models [2] recycles 0 hard 0 soft 0.67 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.89 ptm 0.06 rmsd 0.38
# 203 models [4] recycles 0 hard 0 soft 0.68 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.90 ptm 0.06 rmsd 0.35
# 204 models [1] recycles 0 hard 0 soft 0.68 temp 1 seqid 0.29 loss 1.34 dgram_cce 1.34 plddt 0.90 ptm 0.07 rmsd 0.35
# 205 models [0] recycles 0 hard 0 soft 0.68 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.94 ptm 0.07 rmsd 0.34
# 206 models [0] recycles 0 hard 0 soft 0.69 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.93 ptm 0.07 rmsd 0.46
# 207 models [4] recycles 0 hard 0 soft 0.69 temp 1 seqid 0.29 loss 1.57 dgram_cce 1.57 plddt 0.91 ptm 0.07 rmsd 0.39
# 208 models [3] recycles 0 hard 0 soft 0.69 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.90 ptm 0.06 rmsd 0.56
# 209 models [3] recycles 0 hard 0 soft 0.70 temp 1 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.90 ptm 0.06 rmsd 0.47
# 210 models [2] recycles 0 hard 0 soft 0.70 temp 1 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.87 ptm 0.06 rmsd 0.40
# 211 models [1] recycles 0 hard 0 soft 0.70 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.92 ptm 0.07 rmsd 0.45
# 212 models [3] recycles 0 hard 0 soft 0.71 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.88 ptm 0.06 rmsd 0.45
# 213 models [3] recycles 0 hard 0 soft 0.71 temp 1 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.93 ptm 0.06 rmsd 0.41
# 214 models [3] recycles 0 hard 0 soft 0.71 temp 1 seqid 0.29 loss 1.36 dgram_cce 1.36 plddt 0.92 ptm 0.06 rmsd 0.41
# 215 models [2] recycles 0 hard 0 soft 0.72 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.89 ptm 0.06 rmsd 0.42
# 216 models [3] recycles 0 hard 0 soft 0.72 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.89 ptm 0.06 rmsd 0.32
# 217 models [0] recycles 0 hard 0 soft 0.72 temp 1 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.93 ptm 0.07 rmsd 0.26
# 218 models [3] recycles 0 hard 0 soft 0.73 temp 1 seqid 0.29 loss 1.38 dgram_cce 1.38 plddt 0.89 ptm 0.07 rmsd 0.35
# 219 models [1] recycles 0 hard 0 soft 0.73 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.87 ptm 0.07 rmsd 0.45
# 220 models [2] recycles 0 hard 0 soft 0.73 temp 1 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.92 ptm 0.07 rmsd 0.32
# 221 models [1] recycles 0 hard 0 soft 0.74 temp 1 seqid 0.29 loss 1.34 dgram_cce 1.34 plddt 0.85 ptm 0.07 rmsd 0.43
# 222 models [0] recycles 0 hard 0 soft 0.74 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.89 ptm 0.06 rmsd 0.41
# 223 models [0] recycles 0 hard 0 soft 0.74 temp 1 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.92 ptm 0.07 rmsd 0.37
# 224 models [1] recycles 0 hard 0 soft 0.75 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.89 ptm 0.07 rmsd 0.41
# 225 models [0] recycles 0 hard 0 soft 0.75 temp 1 seqid 0.29 loss 1.52 dgram_cce 1.52 plddt 0.90 ptm 0.06 rmsd 0.38
# 226 models [3] recycles 0 hard 0 soft 0.75 temp 1 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.92 ptm 0.06 rmsd 0.44
# 227 models [2] recycles 0 hard 0 soft 0.76 temp 1 seqid 0.29 loss 1.34 dgram_cce 1.34 plddt 0.90 ptm 0.07 rmsd 0.39
# 228 models [1] recycles 0 hard 0 soft 0.76 temp 1 seqid 0.29 loss 1.33 dgram_cce 1.33 plddt 0.87 ptm 0.07 rmsd 0.48
# 229 models [4] recycles 0 hard 0 soft 0.76 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.89 ptm 0.07 rmsd 0.38
# 230 models [0] recycles 0 hard 0 soft 0.77 temp 1 seqid 0.29 loss 1.37 dgram_cce 1.37 plddt 0.92 ptm 0.07 rmsd 0.29
# 231 models [1] recycles 0 hard 0 soft 0.77 temp 1 seqid 0.29 loss 1.27 dgram_cce 1.27 plddt 0.89 ptm 0.07 rmsd 0.39
# 232 models [4] recycles 0 hard 0 soft 0.77 temp 1 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.93 ptm 0.07 rmsd 0.39
# 233 models [2] recycles 0 hard 0 soft 0.78 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.86 ptm 0.07 rmsd 0.41
# 234 models [0] recycles 0 hard 0 soft 0.78 temp 1 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.91 ptm 0.06 rmsd 0.22
# 235 models [4] recycles 0 hard 0 soft 0.78 temp 1 seqid 0.29 loss 1.35 dgram_cce 1.35 plddt 0.92 ptm 0.07 rmsd 0.41
# 236 models [2] recycles 0 hard 0 soft 0.79 temp 1 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.91 ptm 0.06 rmsd 0.36
# 237 models [3] recycles 0 hard 0 soft 0.79 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.83 ptm 0.06 rmsd 0.33
# 238 models [4] recycles 0 hard 0 soft 0.79 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.88 ptm 0.07 rmsd 0.43
# 239 models [4] recycles 0 hard 0 soft 0.80 temp 1 seqid 0.29 loss 1.34 dgram_cce 1.34 plddt 0.91 ptm 0.07 rmsd 0.34
# 240 models [3] recycles 0 hard 0 soft 0.80 temp 1 seqid 0.29 loss 1.23 dgram_cce 1.23 plddt 0.94 ptm 0.07 rmsd 0.34
# 241 models [0] recycles 0 hard 0 soft 0.80 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.91 ptm 0.07 rmsd 0.35
# 242 models [4] recycles 0 hard 0 soft 0.81 temp 1 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.87 ptm 0.06 rmsd 0.40
# 243 models [3] recycles 0 hard 0 soft 0.81 temp 1 seqid 0.29 loss 1.37 dgram_cce 1.37 plddt 0.94 ptm 0.07 rmsd 0.41
# 244 models [3] recycles 0 hard 0 soft 0.81 temp 1 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.91 ptm 0.06 rmsd 0.38
# 245 models [0] recycles 0 hard 0 soft 0.82 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.90 ptm 0.07 rmsd 0.30
# 246 models [4] recycles 0 hard 0 soft 0.82 temp 1 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.88 ptm 0.07 rmsd 0.33
# 247 models [3] recycles 0 hard 0 soft 0.82 temp 1 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.90 ptm 0.06 rmsd 0.40
# 248 models [4] recycles 0 hard 0 soft 0.83 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.91 ptm 0.07 rmsd 0.34
# 249 models [2] recycles 0 hard 0 soft 0.83 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.93 ptm 0.07 rmsd 0.39
# 250 models [1] recycles 0 hard 0 soft 0.83 temp 1 seqid 0.29 loss 1.30 dgram_cce 1.30 plddt 0.89 ptm 0.07 rmsd 0.40
# 251 models [3] recycles 0 hard 0 soft 0.84 temp 1 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.88 ptm 0.06 rmsd 0.41
# 252 models [2] recycles 0 hard 0 soft 0.84 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.91 ptm 0.07 rmsd 0.36
# 253 models [1] recycles 0 hard 0 soft 0.84 temp 1 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.89 ptm 0.07 rmsd 0.36
# 254 models [1] recycles 0 hard 0 soft 0.85 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.90 ptm 0.07 rmsd 0.40
# 255 models [0] recycles 0 hard 0 soft 0.85 temp 1 seqid 0.29 loss 1.35 dgram_cce 1.35 plddt 0.92 ptm 0.07 rmsd 0.34
# 256 models [2] recycles 0 hard 0 soft 0.85 temp 1 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.91 ptm 0.07 rmsd 0.42
# 257 models [1] recycles 0 hard 0 soft 0.86 temp 1 seqid 0.29 loss 1.28 dgram_cce 1.28 plddt 0.90 ptm 0.07 rmsd 0.29
# 258 models [0] recycles 0 hard 0 soft 0.86 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.88 ptm 0.07 rmsd 0.27
# 259 models [3] recycles 0 hard 0 soft 0.86 temp 1 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.86 ptm 0.06 rmsd 0.43
# 260 models [4] recycles 0 hard 0 soft 0.87 temp 1 seqid 0.29 loss 1.57 dgram_cce 1.57 plddt 0.90 ptm 0.07 rmsd 0.45
# 261 models [4] recycles 0 hard 0 soft 0.87 temp 1 seqid 0.29 loss 1.33 dgram_cce 1.33 plddt 0.91 ptm 0.07 rmsd 0.41
# 262 models [2] recycles 0 hard 0 soft 0.87 temp 1 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.91 ptm 0.07 rmsd 0.41
# 263 models [2] recycles 0 hard 0 soft 0.88 temp 1 seqid 0.29 loss 1.35 dgram_cce 1.35 plddt 0.92 ptm 0.07 rmsd 0.39
# 264 models [4] recycles 0 hard 0 soft 0.88 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.89 ptm 0.07 rmsd 0.37
# 265 models [4] recycles 0 hard 0 soft 0.88 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.91 ptm 0.07 rmsd 0.37
# 266 models [2] recycles 0 hard 0 soft 0.89 temp 1 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.87 ptm 0.07 rmsd 0.52
# 267 models [0] recycles 0 hard 0 soft 0.89 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.89 ptm 0.06 rmsd 0.32
# 268 models [1] recycles 0 hard 0 soft 0.89 temp 1 seqid 0.29 loss 1.35 dgram_cce 1.35 plddt 0.89 ptm 0.07 rmsd 0.43
# 269 models [4] recycles 0 hard 0 soft 0.90 temp 1 seqid 0.29 loss 1.35 dgram_cce 1.35 plddt 0.94 ptm 0.07 rmsd 0.33
# 270 models [1] recycles 0 hard 0 soft 0.90 temp 1 seqid 0.29 loss 1.34 dgram_cce 1.34 plddt 0.91 ptm 0.07 rmsd 0.34
# 271 models [4] recycles 0 hard 0 soft 0.90 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.92 ptm 0.07 rmsd 0.30
# 272 models [1] recycles 0 hard 0 soft 0.91 temp 1 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.90 ptm 0.07 rmsd 0.45
# 273 models [1] recycles 0 hard 0 soft 0.91 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.88 ptm 0.07 rmsd 0.38
# 274 models [3] recycles 0 hard 0 soft 0.91 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.89 ptm 0.07 rmsd 0.39
# 275 models [2] recycles 0 hard 0 soft 0.92 temp 1 seqid 0.29 loss 1.60 dgram_cce 1.60 plddt 0.87 ptm 0.07 rmsd 0.48
# 276 models [1] recycles 0 hard 0 soft 0.92 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.89 ptm 0.07 rmsd 0.45
# 277 models [2] recycles 0 hard 0 soft 0.92 temp 1 seqid 0.29 loss 1.56 dgram_cce 1.56 plddt 0.89 ptm 0.07 rmsd 0.41
# 278 models [1] recycles 0 hard 0 soft 0.93 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.85 ptm 0.07 rmsd 0.36
# 279 models [1] recycles 0 hard 0 soft 0.93 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.87 ptm 0.07 rmsd 0.41
# 280 models [1] recycles 0 hard 0 soft 0.93 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.89 ptm 0.06 rmsd 0.35
# 281 models [1] recycles 0 hard 0 soft 0.94 temp 1 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.87 ptm 0.07 rmsd 0.46
# 282 models [0] recycles 0 hard 0 soft 0.94 temp 1 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.93 ptm 0.07 rmsd 0.29
# 283 models [1] recycles 0 hard 0 soft 0.94 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.88 ptm 0.07 rmsd 0.34
# 284 models [0] recycles 0 hard 0 soft 0.95 temp 1 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.87 ptm 0.06 rmsd 0.42
# 285 models [2] recycles 0 hard 0 soft 0.95 temp 1 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.87 ptm 0.06 rmsd 0.43
# 286 models [1] recycles 0 hard 0 soft 0.95 temp 1 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.85 ptm 0.06 rmsd 0.39
# 287 models [3] recycles 0 hard 0 soft 0.96 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.89 ptm 0.06 rmsd 0.41
# 288 models [1] recycles 0 hard 0 soft 0.96 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.83 ptm 0.06 rmsd 0.37
# 289 models [0] recycles 0 hard 0 soft 0.96 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.89 ptm 0.07 rmsd 0.31
# 290 models [0] recycles 0 hard 0 soft 0.97 temp 1 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.88 ptm 0.06 rmsd 0.41
# 291 models [2] recycles 0 hard 0 soft 0.97 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.89 ptm 0.07 rmsd 0.47
# 292 models [0] recycles 0 hard 0 soft 0.97 temp 1 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.88 ptm 0.06 rmsd 0.33
# 293 models [1] recycles 0 hard 0 soft 0.98 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.87 ptm 0.06 rmsd 0.36
# 294 models [3] recycles 0 hard 0 soft 0.98 temp 1 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.88 ptm 0.06 rmsd 0.40
# 295 models [3] recycles 0 hard 0 soft 0.98 temp 1 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.82 ptm 0.06 rmsd 0.33
# 296 models [4] recycles 0 hard 0 soft 0.99 temp 1 seqid 0.29 loss 1.56 dgram_cce 1.56 plddt 0.90 ptm 0.06 rmsd 0.50
# 297 models [1] recycles 0 hard 0 soft 0.99 temp 1 seqid 0.29 loss 1.36 dgram_cce 1.36 plddt 0.87 ptm 0.07 rmsd 0.40
# 298 models [4] recycles 0 hard 0 soft 0.99 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.86 ptm 0.07 rmsd 0.20
# 299 models [4] recycles 0 hard 0 soft 1.00 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.89 ptm 0.07 rmsd 0.35
# 300 models [4] recycles 0 hard 0 soft 1 temp 1 seqid 0.29 loss 1.30 dgram_cce 1.30 plddt 0.92 ptm 0.07 rmsd 0.32
# Stage 2: running (soft → hard)
# 301 models [3] recycles 0 hard 0 soft 1 temp 0.98 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.92 ptm 0.06 rmsd 0.46
# 302 models [3] recycles 0 hard 0 soft 1 temp 0.96 seqid 0.29 loss 1.60 dgram_cce 1.60 plddt 0.88 ptm 0.06 rmsd 0.78
# 303 models [1] recycles 0 hard 0 soft 1 temp 0.94 seqid 0.29 loss 1.57 dgram_cce 1.57 plddt 0.86 ptm 0.06 rmsd 0.47
# 304 models [1] recycles 0 hard 0 soft 1 temp 0.92 seqid 0.29 loss 1.35 dgram_cce 1.35 plddt 0.87 ptm 0.07 rmsd 0.44
# 305 models [4] recycles 0 hard 0 soft 1 temp 0.90 seqid 0.29 loss 1.34 dgram_cce 1.34 plddt 0.91 ptm 0.07 rmsd 0.30
# 306 models [0] recycles 0 hard 0 soft 1 temp 0.88 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.92 ptm 0.06 rmsd 0.35
# 307 models [4] recycles 0 hard 0 soft 1 temp 0.87 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.92 ptm 0.07 rmsd 0.35
# 308 models [3] recycles 0 hard 0 soft 1 temp 0.85 seqid 0.29 loss 1.55 dgram_cce 1.55 plddt 0.81 ptm 0.06 rmsd 0.71
# 309 models [3] recycles 0 hard 0 soft 1 temp 0.83 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.88 ptm 0.06 rmsd 0.52
# 310 models [3] recycles 0 hard 0 soft 1 temp 0.81 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.87 ptm 0.06 rmsd 0.77
# 311 models [4] recycles 0 hard 0 soft 1 temp 0.79 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.89 ptm 0.07 rmsd 0.34
# 312 models [0] recycles 0 hard 0 soft 1 temp 0.78 seqid 0.29 loss 1.69 dgram_cce 1.69 plddt 0.89 ptm 0.06 rmsd 0.59
# 313 models [3] recycles 0 hard 0 soft 1 temp 0.76 seqid 0.29 loss 1.63 dgram_cce 1.63 plddt 0.82 ptm 0.06 rmsd 0.90
# 314 models [3] recycles 0 hard 0 soft 1 temp 0.74 seqid 0.29 loss 1.55 dgram_cce 1.55 plddt 0.86 ptm 0.06 rmsd 0.66
# 315 models [2] recycles 0 hard 0 soft 1 temp 0.73 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.89 ptm 0.07 rmsd 0.64
# 316 models [1] recycles 0 hard 0 soft 1 temp 0.71 seqid 0.29 loss 1.77 dgram_cce 1.77 plddt 0.82 ptm 0.06 rmsd 0.36
# 317 models [2] recycles 0 hard 0 soft 1 temp 0.69 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.87 ptm 0.06 rmsd 0.39
# 318 models [0] recycles 0 hard 0 soft 1 temp 0.68 seqid 0.29 loss 1.92 dgram_cce 1.92 plddt 0.91 ptm 0.06 rmsd 0.51
# 319 models [1] recycles 0 hard 0 soft 1 temp 0.66 seqid 0.29 loss 1.65 dgram_cce 1.65 plddt 0.87 ptm 0.06 rmsd 0.49
# 320 models [3] recycles 0 hard 0 soft 1 temp 0.64 seqid 0.29 loss 1.61 dgram_cce 1.61 plddt 0.88 ptm 0.06 rmsd 0.48
# 321 models [3] recycles 0 hard 0 soft 1 temp 0.63 seqid 0.29 loss 1.86 dgram_cce 1.86 plddt 0.85 ptm 0.06 rmsd 0.57
# 322 models [1] recycles 0 hard 0 soft 1 temp 0.61 seqid 0.29 loss 1.55 dgram_cce 1.55 plddt 0.90 ptm 0.07 rmsd 0.39
# 323 models [2] recycles 0 hard 0 soft 1 temp 0.60 seqid 0.29 loss 1.59 dgram_cce 1.59 plddt 0.89 ptm 0.06 rmsd 0.51
# 324 models [2] recycles 0 hard 0 soft 1 temp 0.58 seqid 0.29 loss 1.89 dgram_cce 1.89 plddt 0.90 ptm 0.06 rmsd 0.55
# 325 models [2] recycles 0 hard 0 soft 1 temp 0.57 seqid 0.29 loss 1.58 dgram_cce 1.58 plddt 0.86 ptm 0.06 rmsd 0.43
# 326 models [3] recycles 0 hard 0 soft 1 temp 0.55 seqid 0.29 loss 1.61 dgram_cce 1.61 plddt 0.86 ptm 0.06 rmsd 0.39
# 327 models [4] recycles 0 hard 0 soft 1 temp 0.54 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.89 ptm 0.06 rmsd 0.37
# 328 models [2] recycles 0 hard 0 soft 1 temp 0.52 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.84 ptm 0.06 rmsd 0.53
# 329 models [2] recycles 0 hard 0 soft 1 temp 0.51 seqid 0.29 loss 1.60 dgram_cce 1.60 plddt 0.86 ptm 0.07 rmsd 0.88
# 330 models [2] recycles 0 hard 0 soft 1 temp 0.50 seqid 0.29 loss 1.58 dgram_cce 1.58 plddt 0.92 ptm 0.07 rmsd 0.62
# 331 models [4] recycles 0 hard 0 soft 1 temp 0.48 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.91 ptm 0.06 rmsd 0.30
# 332 models [4] recycles 0 hard 0 soft 1 temp 0.47 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.88 ptm 0.06 rmsd 0.37
# 333 models [3] recycles 0 hard 0 soft 1 temp 0.45 seqid 0.29 loss 1.63 dgram_cce 1.63 plddt 0.90 ptm 0.06 rmsd 0.41
# 334 models [3] recycles 0 hard 0 soft 1 temp 0.44 seqid 0.29 loss 1.71 dgram_cce 1.71 plddt 0.85 ptm 0.06 rmsd 0.63
# 335 models [2] recycles 0 hard 0 soft 1 temp 0.43 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.89 ptm 0.06 rmsd 0.46
# 336 models [3] recycles 0 hard 0 soft 1 temp 0.42 seqid 0.29 loss 1.68 dgram_cce 1.68 plddt 0.89 ptm 0.06 rmsd 0.38
# 337 models [1] recycles 0 hard 0 soft 1 temp 0.40 seqid 0.29 loss 1.63 dgram_cce 1.63 plddt 0.82 ptm 0.06 rmsd 0.37
# 338 models [1] recycles 0 hard 0 soft 1 temp 0.39 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.88 ptm 0.06 rmsd 0.38
# 339 models [2] recycles 0 hard 0 soft 1 temp 0.38 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.83 ptm 0.06 rmsd 0.50
# 340 models [1] recycles 0 hard 0 soft 1 temp 0.37 seqid 0.29 loss 1.66 dgram_cce 1.66 plddt 0.83 ptm 0.06 rmsd 0.53
# 341 models [4] recycles 0 hard 0 soft 1 temp 0.35 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.91 ptm 0.07 rmsd 0.47
# 342 models [3] recycles 0 hard 0 soft 1 temp 0.34 seqid 0.29 loss 1.63 dgram_cce 1.63 plddt 0.86 ptm 0.06 rmsd 0.60
# 343 models [3] recycles 0 hard 0 soft 1 temp 0.33 seqid 0.29 loss 1.63 dgram_cce 1.63 plddt 0.91 ptm 0.06 rmsd 0.35
# 344 models [2] recycles 0 hard 0 soft 1 temp 0.32 seqid 0.29 loss 1.60 dgram_cce 1.60 plddt 0.93 ptm 0.07 rmsd 0.49
# 345 models [1] recycles 0 hard 0 soft 1 temp 0.31 seqid 0.29 loss 1.59 dgram_cce 1.59 plddt 0.86 ptm 0.06 rmsd 0.41
# 346 models [0] recycles 0 hard 0 soft 1 temp 0.30 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.91 ptm 0.07 rmsd 0.31
# 347 models [2] recycles 0 hard 0 soft 1 temp 0.29 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.86 ptm 0.07 rmsd 0.63
# 348 models [0] recycles 0 hard 0 soft 1 temp 0.28 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.82 ptm 0.06 rmsd 0.52
# 349 models [0] recycles 0 hard 0 soft 1 temp 0.27 seqid 0.29 loss 1.52 dgram_cce 1.52 plddt 0.85 ptm 0.06 rmsd 0.41
# 350 models [3] recycles 0 hard 0 soft 1 temp 0.26 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.84 ptm 0.06 rmsd 0.84
# 351 models [3] recycles 0 hard 0 soft 1 temp 0.25 seqid 0.29 loss 1.57 dgram_cce 1.57 plddt 0.86 ptm 0.06 rmsd 0.57
# 352 models [4] recycles 0 hard 0 soft 1 temp 0.24 seqid 0.29 loss 1.68 dgram_cce 1.68 plddt 0.78 ptm 0.06 rmsd 1.20
# 353 models [3] recycles 0 hard 0 soft 1 temp 0.23 seqid 0.29 loss 1.52 dgram_cce 1.52 plddt 0.82 ptm 0.06 rmsd 0.62
# 354 models [4] recycles 0 hard 0 soft 1 temp 0.22 seqid 0.29 loss 1.52 dgram_cce 1.52 plddt 0.86 ptm 0.07 rmsd 0.33
# 355 models [1] recycles 0 hard 0 soft 1 temp 0.21 seqid 0.29 loss 1.85 dgram_cce 1.85 plddt 0.87 ptm 0.06 rmsd 0.50
# 356 models [2] recycles 0 hard 0 soft 1 temp 0.20 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.88 ptm 0.06 rmsd 0.55
# 357 models [4] recycles 0 hard 0 soft 1 temp 0.19 seqid 0.29 loss 1.58 dgram_cce 1.58 plddt 0.92 ptm 0.06 rmsd 0.44
# 358 models [3] recycles 0 hard 0 soft 1 temp 0.18 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.89 ptm 0.06 rmsd 0.51
# 359 models [0] recycles 0 hard 0 soft 1 temp 0.18 seqid 0.29 loss 1.52 dgram_cce 1.52 plddt 0.91 ptm 0.06 rmsd 0.36
# 360 models [2] recycles 0 hard 0 soft 1 temp 0.17 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.87 ptm 0.07 rmsd 0.62
# 361 models [2] recycles 0 hard 0 soft 1 temp 0.16 seqid 0.29 loss 1.60 dgram_cce 1.60 plddt 0.89 ptm 0.06 rmsd 0.43
# 362 models [3] recycles 0 hard 0 soft 1 temp 0.15 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.83 ptm 0.06 rmsd 0.39
# 363 models [1] recycles 0 hard 0 soft 1 temp 0.15 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.90 ptm 0.07 rmsd 0.41
# 364 models [0] recycles 0 hard 0 soft 1 temp 0.14 seqid 0.29 loss 1.58 dgram_cce 1.58 plddt 0.89 ptm 0.06 rmsd 0.51
# 365 models [4] recycles 0 hard 0 soft 1 temp 0.13 seqid 0.29 loss 1.59 dgram_cce 1.59 plddt 0.91 ptm 0.06 rmsd 0.57
# 366 models [0] recycles 0 hard 0 soft 1 temp 0.12 seqid 0.29 loss 1.81 dgram_cce 1.81 plddt 0.90 ptm 0.06 rmsd 0.53
# 367 models [0] recycles 0 hard 0 soft 1 temp 0.12 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.83 ptm 0.06 rmsd 0.32
# 368 models [2] recycles 0 hard 0 soft 1 temp 0.11 seqid 0.14 loss 1.74 dgram_cce 1.74 plddt 0.89 ptm 0.07 rmsd 0.72
# 369 models [2] recycles 0 hard 0 soft 1 temp 0.11 seqid 0.29 loss 1.59 dgram_cce 1.59 plddt 0.88 ptm 0.06 rmsd 0.50
# 370 models [2] recycles 0 hard 0 soft 1 temp 0.10 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.86 ptm 0.07 rmsd 0.45
# 371 models [3] recycles 0 hard 0 soft 1 temp 0.09 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.84 ptm 0.06 rmsd 0.74
# 372 models [0] recycles 0 hard 0 soft 1 temp 0.09 seqid 0.29 loss 1.55 dgram_cce 1.55 plddt 0.85 ptm 0.06 rmsd 0.45
# 373 models [1] recycles 0 hard 0 soft 1 temp 0.08 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.84 ptm 0.06 rmsd 0.46
# 374 models [1] recycles 0 hard 0 soft 1 temp 0.08 seqid 0.29 loss 1.36 dgram_cce 1.36 plddt 0.90 ptm 0.07 rmsd 0.40
# 375 models [3] recycles 0 hard 0 soft 1 temp 0.07 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.88 ptm 0.07 rmsd 1.00
# 376 models [4] recycles 0 hard 0 soft 1 temp 0.07 seqid 0.29 loss 1.72 dgram_cce 1.72 plddt 0.90 ptm 0.06 rmsd 0.55
# 377 models [0] recycles 0 hard 0 soft 1 temp 0.06 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.88 ptm 0.06 rmsd 0.40
# 378 models [2] recycles 0 hard 0 soft 1 temp 0.06 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.88 ptm 0.07 rmsd 0.59
# 379 models [0] recycles 0 hard 0 soft 1 temp 0.05 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.89 ptm 0.06 rmsd 0.38
# 380 models [2] recycles 0 hard 0 soft 1 temp 0.05 seqid 0.14 loss 1.42 dgram_cce 1.42 plddt 0.89 ptm 0.07 rmsd 0.60
# 381 models [1] recycles 0 hard 0 soft 1 temp 0.05 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.85 ptm 0.06 rmsd 0.39
# 382 models [0] recycles 0 hard 0 soft 1 temp 0.04 seqid 0.14 loss 1.60 dgram_cce 1.60 plddt 0.90 ptm 0.06 rmsd 0.38
# 383 models [1] recycles 0 hard 0 soft 1 temp 0.04 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.89 ptm 0.07 rmsd 0.41
# 384 models [0] recycles 0 hard 0 soft 1 temp 0.04 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.89 ptm 0.06 rmsd 0.52
# 385 models [0] recycles 0 hard 0 soft 1 temp 0.03 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.91 ptm 0.06 rmsd 0.35
# 386 models [0] recycles 0 hard 0 soft 1 temp 0.03 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.80 ptm 0.06 rmsd 0.51
# 387 models [2] recycles 0 hard 0 soft 1 temp 0.03 seqid 0.29 loss 1.62 dgram_cce 1.62 plddt 0.86 ptm 0.06 rmsd 0.53
# 388 models [3] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.29 loss 1.62 dgram_cce 1.62 plddt 0.85 ptm 0.06 rmsd 0.46
# 389 models [4] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.29 loss 1.71 dgram_cce 1.71 plddt 0.85 ptm 0.06 rmsd 0.97
# 390 models [2] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.29 loss 1.55 dgram_cce 1.55 plddt 0.88 ptm 0.07 rmsd 0.64
# 391 models [2] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.29 loss 1.56 dgram_cce 1.56 plddt 0.86 ptm 0.07 rmsd 0.82
# 392 models [4] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.29 loss 1.86 dgram_cce 1.86 plddt 0.87 ptm 0.06 rmsd 0.63
# 393 models [4] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.29 loss 1.64 dgram_cce 1.64 plddt 0.89 ptm 0.06 rmsd 0.53
# 394 models [4] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.29 loss 1.60 dgram_cce 1.60 plddt 0.89 ptm 0.06 rmsd 0.40
# 395 models [3] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.29 loss 1.63 dgram_cce 1.63 plddt 0.80 ptm 0.06 rmsd 0.29
# 396 models [0] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.89 ptm 0.06 rmsd 0.32
# 397 models [0] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.29 loss 1.78 dgram_cce 1.78 plddt 0.91 ptm 0.06 rmsd 0.42
# 398 models [1] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.85 ptm 0.07 rmsd 0.42
# 399 models [2] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.29 loss 1.58 dgram_cce 1.58 plddt 0.85 ptm 0.06 rmsd 0.48
# 400 models [4] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.29 loss 1.52 dgram_cce 1.52 plddt 0.88 ptm 0.06 rmsd 0.45
# Stage 3: running (hard)
# 401 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.86 ptm 0.06 rmsd 0.35
# 402 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.86 ptm 0.06 rmsd 0.35
# 403 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.83 ptm 0.07 rmsd 0.51
# 404 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.86 ptm 0.06 rmsd 0.35
# 405 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.83 ptm 0.07 rmsd 0.51
# 406 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.86 ptm 0.06 rmsd 0.35
# 407 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.83 ptm 0.07 rmsd 0.51
# 408 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.86 ptm 0.06 rmsd 0.35
# 409 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.83 ptm 0.07 rmsd 0.51
# 410 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.86 ptm 0.06 rmsd 0.35

# %%
af_model.plot_traj()

# %%
af_model.save_pdb(f"{af_model.protocol}.pdb")
af_model.plot_pdb(show_mainchains=True)
# Out:
# <div id="3dmolviewer_17643903896856592"  style="position: relative; width: 800px; height: 480px;">
#         <p id="3dmolwarning_17643903896856592" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_17643903896856592 = null;
# var warn = document.getElementById("3dmolwarning_17643903896856592");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17643903896856592 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17643903896856592"),{backgroundColor:"white"});
# viewer_17643903896856592.zoomTo();
# 	viewer_17643903896856592.addModel("MODEL       1\nATOM      1  N   GLY A   1       1.701   2.454  -0.394  1.00 81.62           N  \nATOM      2  CA  GLY A   1       3.001   1.813  -0.521  1.00 81.62           C  \nATOM      3  C   GLY A   1       3.358   0.947   0.672  1.00 81.62           C  \nATOM      4  O   GLY A   1       4.490   0.471   0.783  1.00 81.62           O  \nATOM      5  N   ASP A   2       2.607   0.092   0.892  1.00 82.34           N  \nATOM      6  CA  ASP A   2       2.774  -1.267   1.399  1.00 82.34           C  \nATOM      7  C   ASP A   2       1.707  -2.200   0.830  1.00 82.34           C  \nATOM      8  CB  ASP A   2       2.723  -1.280   2.928  1.00 82.34           C  \nATOM      9  O   ASP A   2       0.601  -1.762   0.506  1.00 82.34           O  \nATOM     10  CG  ASP A   2       3.273  -0.008   3.550  1.00 82.34           C  \nATOM     11  OD1 ASP A   2       4.482   0.270   3.401  1.00 82.34           O  \nATOM     12  OD2 ASP A   2       2.490   0.720   4.198  1.00 82.34           O  \nATOM     13  N   PRO A   3       2.152  -3.540   0.777  1.00 82.93           N  \nATOM     14  CA  PRO A   3       1.189  -4.447   0.150  1.00 82.93           C  \nATOM     15  C   PRO A   3      -0.075  -4.636   0.985  1.00 82.93           C  \nATOM     16  CB  PRO A   3       1.967  -5.760   0.032  1.00 82.93           C  \nATOM     17  O   PRO A   3       0.009  -4.866   2.195  1.00 82.93           O  \nATOM     18  CG  PRO A   3       3.401  -5.371   0.191  1.00 82.93           C  \nATOM     19  CD  PRO A   3       3.467  -4.128   1.033  1.00 82.93           C  \nATOM     20  N   GLY A   4      -0.963  -4.141   0.394  1.00 84.80           N  \nATOM     21  CA  GLY A   4      -2.352  -4.139   0.823  1.00 84.80           C  \nATOM     22  C   GLY A   4      -2.867  -2.755   1.172  1.00 84.80           C  \nATOM     23  O   GLY A   4      -4.055  -2.581   1.449  1.00 84.80           O  \nATOM     24  N   SER A   5      -2.177  -1.867   0.950  1.00 87.26           N  \nATOM     25  CA  SER A   5      -2.689  -0.506   1.070  1.00 87.26           C  \nATOM     26  C   SER A   5      -2.304   0.338  -0.141  1.00 87.26           C  \nATOM     27  CB  SER A   5      -2.166   0.153   2.347  1.00 87.26           C  \nATOM     28  O   SER A   5      -1.173   0.262  -0.623  1.00 87.26           O  \nATOM     29  OG  SER A   5      -2.709  -0.476   3.496  1.00 87.26           O  \nATOM     30  N   PRO A   6      -3.021   0.971  -0.766  1.00 89.90           N  \nATOM     31  CA  PRO A   6      -2.884   1.889  -1.899  1.00 89.90           C  \nATOM     32  C   PRO A   6      -1.828   2.966  -1.660  1.00 89.90           C  \nATOM     33  CB  PRO A   6      -4.278   2.508  -2.022  1.00 89.90           C  \nATOM     34  O   PRO A   6      -1.412   3.647  -2.601  1.00 89.90           O  \nATOM     35  CG  PRO A   6      -4.962   2.167  -0.737  1.00 89.90           C  \nATOM     36  CD  PRO A   6      -4.239   1.013  -0.104  1.00 89.90           C  \nATOM     37  N   HIS A   7      -1.022   2.940  -0.504  1.00 88.18           N  \nATOM     38  CA  HIS A   7      -0.030   3.939  -0.122  1.00 88.18           C  \nATOM     39  C   HIS A   7       1.317   3.291   0.182  1.00 88.18           C  \nATOM     40  CB  HIS A   7      -0.513   4.737   1.091  1.00 88.18           C  \nATOM     41  O   HIS A   7       2.230   3.951   0.682  1.00 88.18           O  \nATOM     42  CG  HIS A   7      -1.839   5.397   0.884  1.00 88.18           C  \nATOM     43  CD2 HIS A   7      -2.167   6.562   0.277  1.00 88.18           C  \nATOM     44  ND1 HIS A   7      -3.021   4.851   1.335  1.00 88.18           N  \nATOM     45  CE1 HIS A   7      -4.022   5.653   1.012  1.00 88.18           C  \nATOM     46  NE2 HIS A   7      -3.531   6.699   0.370  1.00 88.18           N  \nENDMDL\nMODEL       2\nATOM      1  N   GLY A   1       1.564   2.228  -0.546  1.00 76.76           N  \nATOM      2  CA  GLY A   1       2.863   1.606  -0.747  1.00 76.76       ...

# %%
HTML(af_model.animate())
# Out:
# <video width="800" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
af_model.get_seqs()
# Out:
# ['GDPGSPH']

# %% [markdown]
# # hallucination (~1 minute)
# For a given length, generate/hallucinate a protein sequence that AlphaFold thinks folds into a well structured protein (high plddt, low pae, many contacts).

# %%
clear_mem()
af_model = mk_afdesign_model(protocol="hallucination")
af_model.prep_inputs(length=13, rm_aa="C")
add_cyclic_offset(af_model)
# add_rg_loss(af_model)

print("length",af_model._len)
print("weights",af_model.opt["weights"])
# Out:
# length 13
# weights {'con': 1.0, 'exp_res': 0.0, 'helix': 0.0, 'pae': 0.0, 'plddt': 0.0, 'seq_ent': 0.0}

# %%
# pre-design with gumbel initialization and softmax activation
af_model.restart()
af_model.set_seq(mode="gumbel")
af_model.set_opt("con", binary=True, cutoff=21.6875, num=af_model._len, seqsep=0)
af_model.set_weights(pae=1, plddt=1, con=0.5)
af_model.design_soft(50)

# three stage design
af_model.set_seq(seq=af_model.aux["seq"]["pseudo"])
af_model.design_3stage(50,50,10)
# Out:
# 1 models [0] recycles 0 hard 0 soft 1 temp 1 loss 0.63 pae 0.22 con 0.00 plddt 0.59 ptm 0.03
# 2 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.62 pae 0.21 con 0.00 plddt 0.59 ptm 0.03
# 3 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.60 pae 0.21 con 0.00 plddt 0.61 ptm 0.03
# 4 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.62 pae 0.20 con 0.00 plddt 0.58 ptm 0.03
# 5 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.56 pae 0.20 con 0.00 plddt 0.64 ptm 0.03
# 6 models [0] recycles 0 hard 0 soft 1 temp 1 loss 0.58 pae 0.21 con 0.00 plddt 0.63 ptm 0.03
# 7 models [0] recycles 0 hard 0 soft 1 temp 1 loss 0.51 pae 0.20 con 0.00 plddt 0.69 ptm 0.03
# 8 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.57 pae 0.21 con 0.00 plddt 0.64 ptm 0.03
# 9 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.59 pae 0.21 con 0.00 plddt 0.62 ptm 0.03
# 10 models [4] recycles 0 hard 0 soft 1 temp 1 loss 0.55 pae 0.20 con 0.00 plddt 0.65 ptm 0.03
# 11 models [0] recycles 0 hard 0 soft 1 temp 1 loss 0.50 pae 0.20 con 0.00 plddt 0.70 ptm 0.03
# 12 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.57 pae 0.22 con 0.00 plddt 0.66 ptm 0.03
# 13 models [0] recycles 0 hard 0 soft 1 temp 1 loss 0.55 pae 0.19 con 0.00 plddt 0.64 ptm 0.03
# 14 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.54 pae 0.21 con 0.00 plddt 0.66 ptm 0.03
# 15 models [4] recycles 0 hard 0 soft 1 temp 1 loss 0.56 pae 0.20 con 0.00 plddt 0.63 ptm 0.03
# 16 models [4] recycles 0 hard 0 soft 1 temp 1 loss 0.53 pae 0.19 con 0.00 plddt 0.66 ptm 0.03
# 17 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.54 pae 0.18 con 0.00 plddt 0.64 ptm 0.03
# 18 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.54 pae 0.18 con 0.00 plddt 0.63 ptm 0.03
# 19 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.55 pae 0.19 con 0.00 plddt 0.63 ptm 0.03
# 20 models [0] recycles 0 hard 0 soft 1 temp 1 loss 0.47 pae 0.17 con 0.00 plddt 0.71 ptm 0.03
# 21 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.55 pae 0.18 con 0.00 plddt 0.63 ptm 0.03
# 22 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.55 pae 0.21 con 0.00 plddt 0.66 ptm 0.03
# 23 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.56 pae 0.20 con 0.00 plddt 0.64 ptm 0.03
# 24 models [4] recycles 0 hard 0 soft 1 temp 1 loss 0.54 pae 0.19 con 0.00 plddt 0.65 ptm 0.03
# 25 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.51 pae 0.18 con 0.00 plddt 0.67 ptm 0.03
# 26 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.52 pae 0.20 con 0.00 plddt 0.68 ptm 0.03
# 27 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.48 pae 0.18 con 0.00 plddt 0.69 ptm 0.03
# 28 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.53 pae 0.17 con 0.00 plddt 0.64 ptm 0.03
# 29 models [4] recycles 0 hard 0 soft 1 temp 1 loss 0.54 pae 0.19 con 0.00 plddt 0.66 ptm 0.03
# 30 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.52 pae 0.21 con 0.00 plddt 0.69 ptm 0.03
# 31 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.58 pae 0.19 con 0.00 plddt 0.61 ptm 0.03
# 32 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.55 pae 0.19 con 0.00 plddt 0.64 ptm 0.03
# 33 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.50 pae 0.20 con 0.00 plddt 0.70 ptm 0.03
# 34 models [0] recycles 0 hard 0 soft 1 temp 1 loss 0.56 pae 0.20 con 0.00 plddt 0.64 ptm 0.03
# 35 models [0] recycles 0 hard 0 soft 1 temp 1 loss 0.52 pae 0.18 con 0.00 plddt 0.66 ptm 0.03
# 36 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.53 pae 0.19 con 0.00 plddt 0.65 ptm 0.03
# 37 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.53 pae 0.19 con 0.00 plddt 0.66 ptm 0.03
# 38 models [0] recycles 0 hard 0 soft 1 temp 1 loss 0.52 pae 0.19 con 0.00 plddt 0.67 ptm 0.03
# 39 models [4] recycles 0 hard 0 soft 1 temp 1 loss 0.52 pae 0.19 con 0.00 plddt 0.66 ptm 0.03
# 40 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.50 pae 0.20 con 0.00 plddt 0.70 ptm 0.03
# 41 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.49 pae 0.20 con 0.00 plddt 0.71 ptm 0.03
# 42 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.54 pae 0.18 con 0.00 plddt 0.64 ptm 0.03
# 43 models [4] recycles 0 hard 0 soft 1 temp 1 loss 0.52 pae 0.19 con 0.00 plddt 0.67 ptm 0.03
# 44 models [4] recycles 0 hard 0 soft 1 temp 1 loss 0.54 pae 0.18 con 0.00 plddt 0.64 ptm 0.03
# 45 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.53 pae 0.17 con 0.00 plddt 0.65 ptm 0.03
# 46 models [3] recycles 0 hard 0 soft 1 temp 1 loss 0.50 pae 0.20 con 0.00 plddt 0.70 ptm 0.03
# 47 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.53 pae 0.18 con 0.00 plddt 0.65 ptm 0.03
# 48 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.52 pae 0.18 con 0.00 plddt 0.66 ptm 0.03
# 49 models [1] recycles 0 hard 0 soft 1 temp 1 loss 0.53 pae 0.20 con 0.00 plddt 0.67 ptm 0.03
# 50 models [4] recycles 0 hard 0 soft 1 temp 1 loss 0.50 pae 0.20 con 0.00 plddt 0.70 ptm 0.03
# Stage 1: running (logits → soft)
# 51 models [1] recycles 0 hard 0 soft 0.02 temp 1 loss 0.57 pae 0.21 con 0.00 plddt 0.64 ptm 0.03
# 52 models [3] recycles 0 hard 0 soft 0.04 temp 1 loss 0.51 pae 0.19 con 0.00 plddt 0.68 ptm 0.03
# 53 models [2] recycles 0 hard 0 soft 0.06 temp 1 loss 0.57 pae 0.18 con 0.00 plddt 0.61 ptm 0.03
# 54 models [1] recycles 0 hard 0 soft 0.08 temp 1 loss 0.52 pae 0.17 con 0.00 plddt 0.65 ptm 0.03
# 55 models [4] recycles 0 hard 0 soft 0.10 temp 1 loss 0.53 pae 0.19 con 0.00 plddt 0.66 ptm 0.03
# 56 models [1] recycles 0 hard 0 soft 0.12 temp 1 loss 0.48 pae 0.14 con 0.00 plddt 0.66 ptm 0.03
# 57 models [1] recycles 0 hard 0 soft 0.14 temp 1 loss 0.56 pae 0.18 con 0.00 plddt 0.62 ptm 0.03
# 58 models [4] recycles 0 hard 0 soft 0.16 temp 1 loss 0.55 pae 0.18 con 0.00 plddt 0.63 ptm 0.03
# 59 models [2] recycles 0 hard 0 soft 0.18 temp 1 loss 0.49 pae 0.13 con 0.00 plddt 0.63 ptm 0.04
# 60 models [2] recycles 0 hard 0 soft 0.20 temp 1 loss 0.47 pae 0.13 con 0.00 plddt 0.66 ptm 0.04
# 61 models [1] recycles 0 hard 0 soft 0.22 temp 1 loss 0.48 pae 0.11 con 0.00 plddt 0.63 ptm 0.04
# 62 models [1] recycles 0 hard 0 soft 0.24 temp 1 loss 0.47 pae 0.11 con 0.00 plddt 0.65 ptm 0.04
# 63 models [1] recycles 0 hard 0 soft 0.26 temp 1 loss 0.43 pae 0.12 con 0.00 plddt 0.69 ptm 0.04
# 64 models [1] recycles 0 hard 0 soft 0.28 temp 1 loss 0.45 pae 0.12 con 0.00 plddt 0.67 ptm 0.04
# 65 models [3] recycles 0 hard 0 soft 0.30 temp 1 loss 0.44 pae 0.15 con 0.00 plddt 0.71 ptm 0.04
# 66 models [1] recycles 0 hard 0 soft 0.32 temp 1 loss 0.43 pae 0.11 con 0.00 plddt 0.68 ptm 0.04
# 67 models [3] recycles 0 hard 0 soft 0.34 temp 1 loss 0.48 pae 0.12 con 0.00 plddt 0.65 ptm 0.04
# 68 models [0] recycles 0 hard 0 soft 0.36 temp 1 loss 0.48 pae 0.13 con 0.00 plddt 0.65 ptm 0.04
# 69 models [1] recycles 0 hard 0 soft 0.38 temp 1 loss 0.45 pae 0.12 con 0.00 plddt 0.67 ptm 0.04
# 70 models [2] recycles 0 hard 0 soft 0.40 temp 1 loss 0.47 pae 0.12 con 0.00 plddt 0.65 ptm 0.04
# 71 models [1] recycles 0 hard 0 soft 0.42 temp 1 loss 0.44 pae 0.13 con 0.00 plddt 0.69 ptm 0.04
# 72 models [0] recycles 0 hard 0 soft 0.44 temp 1 loss 0.49 pae 0.13 con 0.00 plddt 0.64 ptm 0.04
# 73 models [1] recycles 0 hard 0 soft 0.46 temp 1 loss 0.46 pae 0.13 con 0.00 plddt 0.67 ptm 0.04
# 74 models [4] recycles 0 hard 0 soft 0.48 temp 1 loss 0.45 pae 0.14 con 0.00 plddt 0.69 ptm 0.03
# 75 models [0] recycles 0 hard 0 soft 0.50 temp 1 loss 0.52 pae 0.14 con 0.00 plddt 0.62 ptm 0.04
# 76 models [2] recycles 0 hard 0 soft 0.52 temp 1 loss 0.45 pae 0.11 con 0.00 plddt 0.66 ptm 0.04
# 77 models [4] recycles 0 hard 0 soft 0.54 temp 1 loss 0.48 pae 0.15 con 0.00 plddt 0.66 ptm 0.04
# 78 models [0] recycles 0 hard 0 soft 0.56 temp 1 loss 0.47 pae 0.13 con 0.00 plddt 0.67 ptm 0.04
# 79 models [4] recycles 0 hard 0 soft 0.58 temp 1 loss 0.46 pae 0.14 con 0.00 plddt 0.68 ptm 0.04
# 80 models [2] recycles 0 hard 0 soft 0.60 temp 1 loss 0.46 pae 0.13 con 0.00 plddt 0.66 ptm 0.03
# 81 models [0] recycles 0 hard 0 soft 0.62 temp 1 loss 0.44 pae 0.12 con 0.00 plddt 0.68 ptm 0.04
# 82 models [3] recycles 0 hard 0 soft 0.64 temp 1 loss 0.47 pae 0.13 con 0.00 plddt 0.66 ptm 0.03
# 83 models [2] recycles 0 hard 0 soft 0.66 temp 1 loss 0.47 pae 0.12 con 0.00 plddt 0.66 ptm 0.04
# 84 models [4] recycles 0 hard 0 soft 0.68 temp 1 loss 0.43 pae 0.14 con 0.00 plddt 0.71 ptm 0.04
# 85 models [1] recycles 0 hard 0 soft 0.70 temp 1 loss 0.45 pae 0.12 con 0.00 plddt 0.67 ptm 0.04
# 86 models [2] recycles 0 hard 0 soft 0.72 temp 1 loss 0.45 pae 0.11 con 0.00 plddt 0.66 ptm 0.04
# 87 models [3] recycles 0 hard 0 soft 0.74 temp 1 loss 0.44 pae 0.15 con 0.00 plddt 0.71 ptm 0.03
# 88 models [2] recycles 0 hard 0 soft 0.76 temp 1 loss 0.47 pae 0.12 con 0.00 plddt 0.65 ptm 0.04
# 89 models [0] recycles 0 hard 0 soft 0.78 temp 1 loss 0.47 pae 0.14 con 0.00 plddt 0.67 ptm 0.04
# 90 models [3] recycles 0 hard 0 soft 0.80 temp 1 loss 0.48 pae 0.15 con 0.00 plddt 0.67 ptm 0.03
# 91 models [2] recycles 0 hard 0 soft 0.82 temp 1 loss 0.50 pae 0.14 con 0.00 plddt 0.64 ptm 0.04
# 92 models [3] recycles 0 hard 0 soft 0.84 temp 1 loss 0.46 pae 0.15 con 0.00 plddt 0.69 ptm 0.03
# 93 models [2] recycles 0 hard 0 soft 0.86 temp 1 loss 0.45 pae 0.11 con 0.00 plddt 0.66 ptm 0.04
# 94 models [2] recycles 0 hard 0 soft 0.88 temp 1 loss 0.46 pae 0.13 con 0.00 plddt 0.67 ptm 0.04
# 95 models [3] recycles 0 hard 0 soft 0.90 temp 1 loss 0.49 pae 0.16 con 0.00 plddt 0.67 ptm 0.03
# 96 models [2] recycles 0 hard 0 soft 0.92 temp 1 loss 0.49 pae 0.12 con 0.00 plddt 0.63 ptm 0.04
# 97 models [4] recycles 0 hard 0 soft 0.94 temp 1 loss 0.39 pae 0.14 con 0.00 plddt 0.76 ptm 0.04
# 98 models [2] recycles 0 hard 0 soft 0.96 temp 1 loss 0.52 pae 0.13 con 0.00 plddt 0.61 ptm 0.04
# 99 models [2] recycles 0 hard 0 soft 0.98 temp 1 loss 0.50 pae 0.13 con 0.00 plddt 0.63 ptm 0.04
# 100 models [2] recycles 0 hard 0 soft 1 temp 1 loss 0.47 pae 0.13 con 0.00 plddt 0.66 ptm 0.04
# Stage 2: running (soft → hard)
# 101 models [2] recycles 0 hard 0 soft 1 temp 0.96 loss 0.48 pae 0.12 con 0.00 plddt 0.65 ptm 0.04
# 102 models [4] recycles 0 hard 0 soft 1 temp 0.92 loss 0.41 pae 0.15 con 0.00 plddt 0.74 ptm 0.04
# 103 models [3] recycles 0 hard 0 soft 1 temp 0.88 loss 0.51 pae 0.18 con 0.00 plddt 0.67 ptm 0.03
# 104 models [0] recycles 0 hard 0 soft 1 temp 0.85 loss 0.49 pae 0.15 con 0.00 plddt 0.66 ptm 0.04
# 105 models [0] recycles 0 hard 0 soft 1 temp 0.81 loss 0.46 pae 0.14 con 0.00 plddt 0.68 ptm 0.04
# 106 models [0] recycles 0 hard 0 soft 1 temp 0.78 loss 0.45 pae 0.15 con 0.00 plddt 0.70 ptm 0.04
# 107 models [4] recycles 0 hard 0 soft 1 temp 0.74 loss 0.43 pae 0.14 con 0.00 plddt 0.71 ptm 0.03
# 108 models [0] recycles 0 hard 0 soft 1 temp 0.71 loss 0.43 pae 0.13 con 0.00 plddt 0.70 ptm 0.04
# 109 models [4] recycles 0 hard 0 soft 1 temp 0.68 loss 0.43 pae 0.15 con 0.00 plddt 0.72 ptm 0.04
# 110 models [1] recycles 0 hard 0 soft 1 temp 0.64 loss 0.50 pae 0.13 con 0.00 plddt 0.63 ptm 0.04
# 111 models [1] recycles 0 hard 0 soft 1 temp 0.61 loss 0.48 pae 0.12 con 0.00 plddt 0.64 ptm 0.04
# 112 models [2] recycles 0 hard 0 soft 1 temp 0.58 loss 0.50 pae 0.10 con 0.00 plddt 0.60 ptm 0.04
# 113 models [4] recycles 0 hard 0 soft 1 temp 0.55 loss 0.42 pae 0.14 con 0.00 plddt 0.71 ptm 0.04
# 114 models [4] recycles 0 hard 0 soft 1 temp 0.52 loss 0.49 pae 0.16 con 0.00 plddt 0.66 ptm 0.04
# 115 models [3] recycles 0 hard 0 soft 1 temp 0.50 loss 0.47 pae 0.13 con 0.00 plddt 0.66 ptm 0.04
# 116 models [4] recycles 0 hard 0 soft 1 temp 0.47 loss 0.49 pae 0.14 con 0.00 plddt 0.65 ptm 0.04
# 117 models [3] recycles 0 hard 0 soft 1 temp 0.44 loss 0.42 pae 0.11 con 0.00 plddt 0.69 ptm 0.04
# 118 models [3] recycles 0 hard 0 soft 1 temp 0.42 loss 0.45 pae 0.12 con 0.00 plddt 0.67 ptm 0.04
# 119 models [1] recycles 0 hard 0 soft 1 temp 0.39 loss 0.47 pae 0.13 con 0.00 plddt 0.67 ptm 0.04
# 120 models [3] recycles 0 hard 0 soft 1 temp 0.37 loss 0.46 pae 0.12 con 0.00 plddt 0.67 ptm 0.04
# 121 models [3] recycles 0 hard 0 soft 1 temp 0.34 loss 0.48 pae 0.12 con 0.00 plddt 0.64 ptm 0.04
# 122 models [0] recycles 0 hard 0 soft 1 temp 0.32 loss 0.50 pae 0.13 con 0.00 plddt 0.62 ptm 0.04
# 123 models [2] recycles 0 hard 0 soft 1 temp 0.30 loss 0.52 pae 0.13 con 0.00 plddt 0.61 ptm 0.04
# 124 models [1] recycles 0 hard 0 soft 1 temp 0.28 loss 0.49 pae 0.12 con 0.00 plddt 0.63 ptm 0.04
# 125 models [2] recycles 0 hard 0 soft 1 temp 0.26 loss 0.50 pae 0.13 con 0.00 plddt 0.63 ptm 0.04
# 126 models [1] recycles 0 hard 0 soft 1 temp 0.24 loss 0.55 pae 0.14 con 0.00 plddt 0.60 ptm 0.04
# 127 models [4] recycles 0 hard 0 soft 1 temp 0.22 loss 0.57 pae 0.16 con 0.00 plddt 0.59 ptm 0.03
# 128 models [1] recycles 0 hard 0 soft 1 temp 0.20 loss 0.53 pae 0.13 con 0.00 plddt 0.60 ptm 0.04
# 129 models [2] recycles 0 hard 0 soft 1 temp 0.18 loss 0.53 pae 0.14 con 0.00 plddt 0.62 ptm 0.04
# 130 models [2] recycles 0 hard 0 soft 1 temp 0.17 loss 0.54 pae 0.15 con 0.00 plddt 0.62 ptm 0.04
# 131 models [2] recycles 0 hard 0 soft 1 temp 0.15 loss 0.50 pae 0.13 con 0.00 plddt 0.63 ptm 0.04
# 132 models [2] recycles 0 hard 0 soft 1 temp 0.14 loss 0.55 pae 0.14 con 0.00 plddt 0.59 ptm 0.04
# 133 models [1] recycles 0 hard 0 soft 1 temp 0.12 loss 0.54 pae 0.14 con 0.00 plddt 0.60 ptm 0.04
# 134 models [4] recycles 0 hard 0 soft 1 temp 0.11 loss 0.52 pae 0.14 con 0.00 plddt 0.63 ptm 0.04
# 135 models [3] recycles 0 hard 0 soft 1 temp 0.10 loss 0.48 pae 0.14 con 0.00 plddt 0.66 ptm 0.04
# 136 models [3] recycles 0 hard 0 soft 1 temp 0.09 loss 0.51 pae 0.13 con 0.00 plddt 0.62 ptm 0.04
# 137 models [4] recycles 0 hard 0 soft 1 temp 0.08 loss 0.57 pae 0.15 con 0.00 plddt 0.58 ptm 0.04
# 138 models [3] recycles 0 hard 0 soft 1 temp 0.07 loss 0.49 pae 0.13 con 0.00 plddt 0.63 ptm 0.04
# 139 models [3] recycles 0 hard 0 soft 1 temp 0.06 loss 0.53 pae 0.14 con 0.00 plddt 0.60 ptm 0.04
# 140 models [2] recycles 0 hard 0 soft 1 temp 0.05 loss 0.50 pae 0.15 con 0.00 plddt 0.65 ptm 0.04
# 141 models [1] recycles 0 hard 0 soft 1 temp 0.04 loss 0.55 pae 0.14 con 0.00 plddt 0.59 ptm 0.04
# 142 models [0] recycles 0 hard 0 soft 1 temp 0.04 loss 0.52 pae 0.14 con 0.00 plddt 0.62 ptm 0.04
# 143 models [0] recycles 0 hard 0 soft 1 temp 0.03 loss 0.51 pae 0.14 con 0.00 plddt 0.63 ptm 0.04
# 144 models [2] recycles 0 hard 0 soft 1 temp 0.02 loss 0.54 pae 0.15 con 0.00 plddt 0.61 ptm 0.04
# 145 models [1] recycles 0 hard 0 soft 1 temp 0.02 loss 0.58 pae 0.15 con 0.00 plddt 0.57 ptm 0.04
# 146 models [0] recycles 0 hard 0 soft 1 temp 0.02 loss 0.50 pae 0.13 con 0.00 plddt 0.63 ptm 0.04
# 147 models [0] recycles 0 hard 0 soft 1 temp 0.01 loss 0.51 pae 0.16 con 0.00 plddt 0.65 ptm 0.04
# 148 models [0] recycles 0 hard 0 soft 1 temp 0.01 loss 0.50 pae 0.14 con 0.00 plddt 0.64 ptm 0.04
# 149 models [3] recycles 0 hard 0 soft 1 temp 0.01 loss 0.46 pae 0.13 con 0.00 plddt 0.67 ptm 0.04
# 150 models [3] recycles 0 hard 0 soft 1 temp 0.01 loss 0.53 pae 0.14 con 0.00 plddt 0.61 ptm 0.04
# Stage 3: running (hard)
# 151 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04
# 152 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04
# 153 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04
# 154 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04
# 155 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04
# 156 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04
# 157 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04
# 158 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04
# 159 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04
# 160 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 loss 0.56 pae 0.14 con 0.00 plddt 0.57 ptm 0.04

# %%
af_model.save_pdb(f"{af_model.protocol}.pdb")
af_model.plot_pdb(show_mainchains=True)
# Out:
# <div id="3dmolviewer_17643905077277765"  style="position: relative; width: 800px; height: 480px;">
#         <p id="3dmolwarning_17643905077277765" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_17643905077277765 = null;
# var warn = document.getElementById("3dmolwarning_17643905077277765");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17643905077277765 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17643905077277765"),{backgroundColor:"white"});
# viewer_17643905077277765.zoomTo();
# 	viewer_17643905077277765.addModel("MODEL       1\nATOM      1  N   ILE A   1       9.859  -4.712  -5.288  1.00 69.92           N  \nATOM      2  CA  ILE A   1       9.666  -3.275  -5.451  1.00 69.92           C  \nATOM      3  C   ILE A   1       8.675  -2.765  -4.407  1.00 69.92           C  \nATOM      4  CB  ILE A   1       9.172  -2.929  -6.873  1.00 69.92           C  \nATOM      5  O   ILE A   1       8.854  -1.679  -3.850  1.00 69.92           O  \nATOM      6  CG1 ILE A   1      10.259  -3.241  -7.908  1.00 69.92           C  \nATOM      7  CG2 ILE A   1       8.744  -1.460  -6.954  1.00 69.92           C  \nATOM      8  CD1 ILE A   1       9.768  -3.220  -9.348  1.00 69.92           C  \nATOM      9  N   TYR A   2       7.619  -3.334  -4.027  1.00 71.19           N  \nATOM     10  CA  TYR A   2       6.643  -3.172  -2.955  1.00 71.19           C  \nATOM     11  C   TYR A   2       7.240  -3.570  -1.610  1.00 71.19           C  \nATOM     12  CB  TYR A   2       5.390  -4.005  -3.237  1.00 71.19           C  \nATOM     13  O   TYR A   2       6.939  -2.954  -0.585  1.00 71.19           O  \nATOM     14  CG  TYR A   2       4.282  -3.794  -2.234  1.00 71.19           C  \nATOM     15  CD1 TYR A   2       4.117  -4.663  -1.157  1.00 71.19           C  \nATOM     16  CD2 TYR A   2       3.399  -2.727  -2.360  1.00 71.19           C  \nATOM     17  CE1 TYR A   2       3.096  -4.473  -0.231  1.00 71.19           C  \nATOM     18  CE2 TYR A   2       2.375  -2.529  -1.440  1.00 71.19           C  \nATOM     19  OH  TYR A   2       1.220  -3.213   0.534  1.00 71.19           O  \nATOM     20  CZ  TYR A   2       2.232  -3.405  -0.380  1.00 71.19           C  \nATOM     21  N   LEU A   3       7.951  -4.582  -1.493  1.00 61.43           N  \nATOM     22  CA  LEU A   3       8.684  -5.090  -0.338  1.00 61.43           C  \nATOM     23  C   LEU A   3       9.820  -4.146   0.043  1.00 61.43           C  \nATOM     24  CB  LEU A   3       9.242  -6.486  -0.629  1.00 61.43           C  \nATOM     25  O   LEU A   3      10.147  -4.007   1.224  1.00 61.43           O  \nATOM     26  CG  LEU A   3       8.666  -7.632   0.204  1.00 61.43           C  \nATOM     27  CD1 LEU A   3       8.401  -8.847  -0.679  1.00 61.43           C  \nATOM     28  CD2 LEU A   3       9.611  -7.991   1.346  1.00 61.43           C  \nATOM     29  N   LEU A   4      10.246  -3.710  -0.910  1.00 63.63           N  \nATOM     30  CA  LEU A   4      11.133  -2.594  -0.599  1.00 63.63           C  \nATOM     31  C   LEU A   4      10.337  -1.386  -0.117  1.00 63.63           C  \nATOM     32  CB  LEU A   4      11.968  -2.214  -1.824  1.00 63.63           C  \nATOM     33  O   LEU A   4      10.781  -0.661   0.777  1.00 63.63           O  \nATOM     34  CG  LEU A   4      13.197  -3.080  -2.102  1.00 63.63           C  \nATOM     35  CD1 LEU A   4      13.722  -2.820  -3.510  1.00 63.63           C  \nATOM     36  CD2 LEU A   4      14.283  -2.817  -1.065  1.00 63.63           C  \nATOM     37  N   VAL A   5       9.129  -1.489  -0.588  1.00 65.39           N  \nATOM     38  CA  VAL A   5       8.165  -0.468  -0.194  1.00 65.39           C  \nATOM     39  C   VAL A   5       6.914  -1.131   0.379  1.00 65.39           C  \nATOM     40  CB  VAL A   5       7.788   0.445  -1.382  1.00 65.39           C  \nATOM     41  O   VAL A   5       6.295  -0.605   1.307  1.00 65.39           O  \nATOM     42  CG1 VAL A   5       6.732   1.467  -0.964  1.00 65.39           C  \nATOM     43  CG2 VAL A   5       9.029   1.148  -1.930  1.00 65.39           C  \nATOM     44  N   SER A   6       6.749  -2.343   0.693  1.00 64.65           N  \nATOM     45  CA  SER A   6       5.720  -3.111   1.387  1.00 64.65           C  \nATOM     46  C   SER A   6       5.739  -4.574   0.958  1.00 64.65           C  \nATOM     47  CB  SER A   6       4.337  -2.513   1.127  1.00 64.65           C  \nATOM     48  O   SER A   6       5.694  -4.877  -0.237  1.00 64.65           O  \nATOM     49   ...

# %%
HTML(af_model.animate())
# Out:
# <video width="800" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
af_model.get_seqs()
# Out:
# ['IYLLVSSMMLILL']
